# %% [markdown]
# # 03 - Recommender System

# %%
# imports
import pandas as pd
import numpy as np

from scipy import sparse # cut down on memory size
from sklearn.metrics.pairwise import pairwise_distances
from sklearn.feature_extraction.text import CountVectorizer

pd.options.display.max_columns = 35

# %% [markdown]
# ___

# %%
# read in the data
df = pd.read_csv('../Data/cards_cleaned.csv')
df.head()
# Out:
#                   name  layout colors color_identity mana_cost  cmc  \
# 0           Static Orb  normal     []             []       {3}  3.0
# 1  Sensory Deprivation  normal  ['U']          ['U']       {U}  1.0
# 2       Road of Return  normal  ['G']          ['G']    {G}{G}  2.0
# 3           Storm Crow  normal  ['U']          ['U']    {1}{U}  2.0
# 4       Walking Sponge  normal  ['U']          ['U']    {1}{U}  2.0
#
#             type_line    card_type super_type sub_type  \
# 0            Artifact     Artifact       NONE     NONE
# 1  Enchantment — Aura  Enchantment       NONE     Aura
# 2             Sorcery      Sorcery       NONE     NONE
# 3     Creature — Bird     Creature       NONE     Bird
# 4   Creature — Sponge     Creature       NONE   Sponge
#
#                                          oracle_text  \
# 0  As long as Static Orb is untapped, players can...
# 1    Enchant creature Enchanted creature gets -3/-0.
# 2  Choose one — • Return target permanent card fr...
# 3  Flying (This creature can't be blocked except ...
# 4  {T}: Target creature loses your choice of flyi...
#
#                                    oracle_text_token  \
# 0  as long as static orb is untapped players can'...
# 1     enchant creature enchanted creature gets -3/-0
# 2  choose one return target permanent card from y...
# 3  flying this creature can't be blocked except b...
# 4  {t} target creature loses your choice of flyin...
#
#                                           legalities    rarity power  \
# 0                      legacy vintage commander duel      rare  NONE
# 1  pioneer modern legacy pauper vintage penny com...    common  NONE
# 2                      legacy vintage commander duel      rare  NONE
# 3  modern legacy pauper vintage penny commander duel    common     1
# 4                      legacy vintage commander duel  uncommon     1
#
#   toughness loyalty card_faces  activated_ability  triggered_ability  \
# 0      NONE    NONE       NONE                0.0                0.0
# 1      NONE    NONE       NONE                0.0                0.0
# 2      NONE    NONE       NONE                0.0                0.0
# 3         2    NONE       NONE                0.0                0.0
# 4         1    NONE       NONE                1.0                0.0
#
#   oracle_text_back oracle_text_back_token colors_back power_back  \
# 0             NONE                   NONE        NONE       NONE
# 1             NONE                   NONE        NONE       NONE
# 2             NONE                   NONE        NONE       NONE
# 3             NONE                   NONE        NONE       NONE
# 4             NONE                   NONE        NONE       NONE
#
#   toughness_back loyalty_back card_type_back super_type_back sub_type_back  \
# 0           NONE         NONE           NONE            NONE          NONE
# 1           NONE         NONE           NONE            NONE          NONE
# 2           NONE         NONE           NONE            NONE          NONE
# 3           NONE         NONE           NONE            NONE          NONE
# 4           NONE         NONE           NONE            NONE          NONE
#
#   mana_cost_back
# 0           NONE
# 1           NONE
# 2           NONE
# 3           NONE
# 4           NONE

# %%
df.shape
# Out:
# (18108, 30)

# %% [markdown]
# ___
#
# ## Oracle text recommender system
# To start I want to build a recommender system that just looks at oracle text. In order to do that I need to combine both oracle_text and oracle_text_back into one single column

# %%
df['oracle_combined'] = df['oracle_text_token'] + " " + df['oracle_text_back_token']

# %%
# start by isolating the name of the card and it's oracle_text
oracle = df['oracle_combined']

# vectorize all our words
cvec = CountVectorizer(stop_words=['none'],
                      min_df=2,
                      max_df=.98,
                      ngram_range=(2,5),
                      token_pattern="[a-zA-Z{}+'0-9-/−]+") # we should use the same RegEx to keep certain characters together 

oracle_vec = cvec.fit_transform(oracle)

# convert to a dataframe so we can use this later on as well
converted_df = pd.DataFrame(oracle_vec.toarray(), columns=cvec.get_feature_names(), index=df['name'])

# %%
converted_df.head()
# Out:
#                      '{t} this  +0/+1 and  +0/+1 and has  +0/+1 counter  \
# name
# Static Orb                   0          0              0              0
# Sensory Deprivation          0          0              0              0
# Road of Return               0          0              0              0
# Storm Crow                   0          0              0              0
# Walking Sponge               0          0              0              0
#
#                      +0/+1 counter on  +0/+1 counters  +0/+1 counters on  \
# name
# Static Orb                          0               0                  0
# Sensory Deprivation                 0               0                  0
# Road of Return                      0               0                  0
# Storm Crow                          0               0                  0
# Walking Sponge                      0               0                  0
#
#                      +0/+1 for  +0/+1 for each  +0/+1 until  +0/+1 until end  \
# name
# Static Orb                   0               0            0                0
# Sensory Deprivation          0               0            0                0
# Road of Return               0               0            0                0
# Storm Crow                   0               0            0                0
# Walking Sponge               0               0            0                0
#
#                      +0/+1 until end of  +0/+1 until end of turn  \
# name
# Static Orb                            0                        0
# Sensory Deprivation                   0                        0
# Road of Return                        0                        0
# Storm Crow                            0                        0
# Walking Sponge                        0                        0
#
#                      +0/+1 whenever  +0/+1 whenever a  +0/+2 and  \
# name
# Static Orb                        0                 0          0
# Sensory Deprivation               0                 0          0
# Road of Return                    0                 0          0
# Storm Crow                        0                 0          0
# Walking Sponge                    0                 0          0
#
#                      +0/+2 and assigns  ...  −8 target opponent gets  \
# name                                    ...
# Static Orb                           0  ...                        0
# Sensory Deprivation                  0  ...                        0
# Road of Return                       0  ...                        0
# Storm Crow                           0  ...                        0
# Walking Sponge                       0  ...                        0
#
#                      −8 target opponent gets an  −8 you  −8 you get  \
# name
# Static Orb                                    0       0           0
# Sensory Deprivation                           0       0           0
# Road of Return                                0       0           0
# Storm Crow                                    0       0           0
# Walking Sponge                                0       0           0
#
#                      −8 you get an  −8 you get an emblem  −9 gain  \
# name
# Static Orb                       0                     0        0
# Sensory Deprivation              0                     0        0
# Road of Return                   0                     0        0
# Storm Crow                       0                     0        0
# Walking Sponge                   0                     0        0
#
#                      −9 gain control  −9 gain control of  −9 put  −9 you  \
# name
# Static Orb                         0                   0       0       0
# Sensory Deprivation                0                   0       0       0
# Road of Return                     0                   0       0       0
# Storm Crow                         0                   0       0       0
# Walking Sponge                     0                   0       0       0
#
#                      −9 you get  −9 you get an  −9 you get an emblem  \
# name
# Static Orb                    0              0                     0
# Sensory Deprivation           0              0                     0
# Road of Return                0              0                     0
# Storm Crow                    0              0                     0
# Walking Sponge                0              0                     0
#
#                      −x chandra  −x return  −x return target
# name
# Static Orb                    0          0                 0
# Sensory Deprivation           0          0                 0
# Road of Return                0          0                 0
# Storm Crow                    0          0                 0
# Walking Sponge                0          0                 0
#
# [5 rows x 96521 columns]

# %% [markdown]
# For the recommender system to work efficiently we need to convert the data back into a sparse matrix with the new names as the index

# %%
sparse_df = sparse.csr_matrix(converted_df)

# %%
# build the recommender system using cosine similarity
rec = pairwise_distances(sparse_df, metric='cosine')

# %%
rec.shape
# Out:
# (18108, 18108)

# %%
rec_df = pd.DataFrame(rec, index=converted_df.index, columns=converted_df.index)
rec_df.head()
# Out:
# name                 Static Orb  Sensory Deprivation  Road of Return  \
# name
# Static Orb                  0.0                  1.0             1.0
# Sensory Deprivation         1.0                  0.0             1.0
# Road of Return              1.0                  1.0             0.0
# Storm Crow                  1.0                  1.0             1.0
# Walking Sponge              1.0                  1.0             1.0
#
# name                 Storm Crow  Walking Sponge  Ravnica at War  \
# name
# Static Orb                  1.0             1.0             1.0
# Sensory Deprivation         1.0             1.0             1.0
# Road of Return              1.0             1.0             1.0
# Storm Crow                  0.0             1.0             1.0
# Walking Sponge              1.0             0.0             1.0
#
# name                 Torrent of Fire  Pteramander  Nantuko Elder  \
# name
# Static Orb                       1.0     1.000000            1.0
# Sensory Deprivation              1.0     1.000000            1.0
# Road of Return                   1.0     0.991151            1.0
# Storm Crow                       1.0     0.986143            1.0
# Walking Sponge                   1.0     1.000000            1.0
#
# name                 Vedalken Heretic  Waterknot  Ruthless Knave  \
# name
# Static Orb                        1.0   1.000000             1.0
# Sensory Deprivation               1.0   0.819813             1.0
# Road of Return                    1.0   1.000000             1.0
# Storm Crow                        1.0   1.000000             1.0
# Walking Sponge                    1.0   1.000000             1.0
#
# name                 Hua Tuo, Honored Physician  Veil of Summer  \
# name
# Static Orb                             1.000000        1.000000
# Sensory Deprivation                    1.000000        1.000000
# Road of Return                         0.935876        1.000000
# Storm Crow                             1.000000        0.977249
# Walking Sponge                         0.983648        0.933317
#
# name                 Disposal Mummy  Marang River Prowler  Aura Graft  ...  \
# name                                                                   ...
# Static Orb                 1.000000              0.947247         1.0  ...
# Sensory Deprivation        1.000000              1.000000         1.0  ...
# Road of Return             0.982848              0.963614         1.0  ...
# Storm Crow                 1.000000              0.943020         1.0  ...
# Walking Sponge             1.000000              1.000000         1.0  ...
#
# name                 Trinket Mage  Skyshroud Blessing  \
# name
# Static Orb               1.000000            1.000000
# Sensory Deprivation      1.000000            1.000000
# Road of Return           0.957119            1.000000
# Storm Crow               1.000000            0.979562
# Walking Sponge           1.000000            0.880192
#
# name                 Omnath, Locus of the Roil  \
# name
# Static Orb                            1.000000
# Sensory Deprivation                   1.000000
# Road of Return                        0.992186
# Storm Crow                            1.000000
# Walking Sponge                        1.000000
#
# name                 Harvest Hand // Scrounged Scythe  Polis Crusher  \
# name
# Static Orb                                   0.963114       1.000000
# Sensory Deprivation                          0.976998       1.000000
# Road of Return                               1.000000       1.000000
# Storm Crow                                   0.867197       0.984492
# Walking Sponge                               1.000000       1.000000
#
# name                 Test of Endurance  Venom Sliver  Borderland Ranger  \
# name
# Static Orb                    1.000000           1.0           1.000000
# Sensory Deprivation           1.000000           1.0           1.000000
# Road of Return                0.985146           1.0           0.951921
# Storm Crow                    1.000000           1.0           1.000000
# Walking Sponge                1.000000           1.0           1.000000
#
# name                 Curse of Thirst  Temporary Truce  Clearwater Goblet  \
# name
# Static Orb                       1.0         0.984595                1.0
# Sensory Deprivation              1.0         1.000000                1.0
# Road of Return                   1.0         1.000000                1.0
# Storm Crow                       1.0         1.000000                1.0
# Walking Sponge                   1.0         1.000000                1.0
#
# name                 Quarry Beetle  Devoted Hero  Without Weakness  \
# name
# Static Orb                1.000000           1.0          1.000000
# Sensory Deprivation       1.000000           1.0          1.000000
# Road of Return            0.856439           1.0          1.000000
# Storm Crow                1.000000           1.0          1.000000
# Walking Sponge            1.000000           1.0          0.914405
#
# name                 Firesong and Sunspeaker  Samut, the Tested  Sinew Sliver
# name
# Static Orb                          1.000000           1.000000           1.0
# Sensory Deprivation                 1.000000           1.000000           1.0
# Road of Return                      1.000000           1.000000           1.0
# Storm Crow                          1.000000           1.000000           1.0
# Walking Sponge                      0.980698           0.913836           1.0
#
# [5 rows x 18108 columns]

# %%
# now to test the recommender system
rec_df['Shock'].sort_values()[1:11]
# Out:
# name
# Tarfire              0.118083
# Unyaro Bee Sting     0.147987
# Moonglove Extract    0.222222
# Goblin Test Pilot    0.242967
# Ember Hauler         0.242967
# Deadapult            0.242967
# Crackling Triton     0.262135
# Tar Pitcher          0.262135
# Orcish Vandal        0.262135
# Magma Jet            0.262135
# Name: Shock, dtype: float64

# %%
rec_df['Static Orb'].sort_values()[1:11]
# Out:
# name
# Winter Orb        0.339828
# Stoic Angel       0.533431
# Damping Field     0.608003
# Imi Statue        0.608003
# Dovin Baan        0.636490
# Mungha Wurm       0.828571
# Storage Matrix    0.845697
# Castle Raptors    0.847279
# Stabilizer        0.857143
# Giant Tortoise    0.870781
# Name: Static Orb, dtype: float64

# %%
rec_df['Prized Amalgam'].sort_values()[1:11]
# Out:
# name
# Bone Dragon               0.463599
# Footsteps of the Goryo    0.527900
# Reassembling Skeleton     0.528050
# Despoiler of Souls        0.538991
# Scrapheap Scrounger       0.544383
# Drownyard Temple          0.547321
# Ghoulsteed                0.547321
# Advanced Stitchwing       0.564410
# Apprentice Necromancer    0.589638
# Wake the Dead             0.598464
# Name: Prized Amalgam, dtype: float64

# %%
rec_df['Wrath of God'].sort_values()[1:11]
# Out:
# name
# Damnation          0.000000
# Perish             0.351819
# Winds of Rath      0.469670
# Kirtar's Wrath     0.498035
# Planar Collapse    0.500000
# Plague Wind        0.537090
# March of Souls     0.539821
# Decree of Pain     0.585977
# Day of Judgment    0.591752
# Rout               0.611078
# Name: Wrath of God, dtype: float64

# %% [markdown]
# This is a great start! Now I want to add the numerical features and see the results
# ___

# %% [markdown]
# ## Adding numerical data to our features

# %%
df.dtypes
# Out:
# name                       object
# layout                     object
# colors                     object
# color_identity             object
# mana_cost                  object
# cmc                       float64
# type_line                  object
# card_type                  object
# super_type                 object
# sub_type                   object
# oracle_text                object
# oracle_text_token          object
# legalities                 object
# rarity                     object
# power                      object
# toughness                  object
# loyalty                    object
# card_faces                 object
# activated_ability         float64
# triggered_ability         float64
# oracle_text_back           object
# oracle_text_back_token     object
# colors_back                object
# power_back                 object
# toughness_back             object
# loyalty_back               object
# card_type_back             object
# super_type_back            object
# sub_type_back              object
# mana_cost_back             object
# oracle_combined            object
# dtype: object

# %%
# we already have a df for the oracle text so we can just use that one and add to it.
converted_df['cmc'] = df['cmc'].values
converted_df['activated_ability'] = df['activated_ability'].values
converted_df['triggered_ability'] = df['triggered_ability'].values

# convert to a sparse matrix
sparse_df = sparse.csr_matrix(converted_df)

# build the recommender system using cosine similarity
rec = pairwise_distances(sparse_df, metric='cosine')

# turn into a dataframe for interpretability
rec_df = pd.DataFrame(rec, index=converted_df.index, columns=converted_df.index)
rec_df.head()
# Out:
# name                 Static Orb  Sensory Deprivation  Road of Return  \
# name
# Static Orb             0.000000             0.898290        0.923837
# Sensory Deprivation    0.898290             0.000000        0.950078
# Road of Return         0.923837             0.950078        0.000000
# Storm Crow             0.883840             0.923861        0.942985
# Walking Sponge         0.887452             0.926229        0.944758
#
# name                 Storm Crow  Walking Sponge  Ravnica at War  \
# name
# Static Orb             0.883840        0.887452        0.628609
# Sensory Deprivation    0.923861        0.926229        0.756568
# Road of Return         0.942985        0.944758        0.817710
# Storm Crow             0.000000        0.915747        0.721981
# Walking Sponge         0.915747        0.000000        0.730626
#
# name                 Torrent of Fire  Pteramander  Nantuko Elder  \
# name
# Static Orb                  0.785099     0.964907       0.672239
# Sensory Deprivation         0.859141     0.976998       0.785166
# Road of Return              0.894520     0.974163       0.839125
# Storm Crow                  0.839128     0.960594       0.754642
# Walking Sponge              0.844130     0.961820       0.722650
#
# name                 Vedalken Heretic  Waterknot  Ruthless Knave  \
# name
# Static Orb                   0.873845   0.853421        0.874734
# Sensory Deprivation          0.917310   0.743795        0.917893
# Road of Return               0.938079   0.928055        0.938516
# Storm Crow                   0.905562   0.890272        0.906227
# Walking Sponge               0.908498   0.893685        0.894000
#
# name                 Hua Tuo, Honored Physician  Veil of Summer  \
# name
# Static Orb                             0.878754        0.971038
# Sensory Deprivation                    0.920528        0.981017
# Road of Return                         0.880978        0.985785
# Storm Crow                             0.909237        0.956639
# Walking Sponge                         0.882745        0.915975
#
# name                 Disposal Mummy  Marang River Prowler  Aura Graft  ...  \
# name                                                                   ...
# Static Orb                 0.819784              0.818056    0.856161  ...
# Sensory Deprivation        0.881875              0.910557    0.905719  ...
# Road of Return             0.896802              0.899534    0.929400  ...
# Storm Crow                 0.865092              0.846774    0.892324  ...
# Walking Sponge             0.869287              0.901026    0.895672  ...
#
# name                 Trinket Mage  Skyshroud Blessing  \
# name
# Static Orb               0.900829            0.899128
# Sensory Deprivation      0.934997            0.933882
# Road of Return           0.910761            0.950489
# Storm Crow               0.925762            0.905610
# Walking Sponge           0.928070            0.817090
#
# name                 Omnath, Locus of the Roil  \
# name
# Static Orb                            0.881229
# Sensory Deprivation                   0.922150
# Road of Return                        0.934417
# Storm Crow                            0.911089
# Walking Sponge                        0.913854
#
# name                 Harvest Hand // Scrounged Scythe  Polis Crusher  \
# name
# Static Orb                                   0.869147       0.854329
# Sensory Deprivation                          0.914231       0.904518
# Road of Return                               0.951830       0.928500
# Storm Crow                                   0.804090       0.877321
# Walking Sponge                               0.928818       0.881136
#
# name                 Test of Endurance  Venom Sliver  Borderland Ranger  \
# name
# Static Orb                    0.798255      0.916016           0.889801
# Sensory Deprivation           0.867764      0.944952           0.927768
# Road of Return                0.888600      0.958778           0.900836
# Storm Crow                    0.848976      0.937131           0.917506
# Walking Sponge                0.853672      0.939086           0.920071
#
# name                 Curse of Thirst  Temporary Truce  Clearwater Goblet  \
# name
# Static Orb                  0.798979         0.903114           0.844774
# Sensory Deprivation         0.868238         0.945567           0.898255
# Road of Return              0.901333         0.959239           0.923810
# Storm Crow                  0.849518         0.937833           0.883799
# Walking Sponge              0.854197         0.939766           0.887413
#
# name                 Quarry Beetle  Devoted Hero  Without Weakness  \
# name
# Static Orb                0.783809      0.606081          0.937124
# Sensory Deprivation       0.858295      0.741801          0.958787
# Road of Return            0.777162      0.806653          0.969138
# Storm Crow                0.838161      0.705116          0.952931
# Walking Sponge            0.843194      0.714286          0.863185
#
# name                 Firesong and Sunspeaker  Samut, the Tested  Sinew Sliver
# name
# Static Orb                          0.761249           0.878070      0.789441
# Sensory Deprivation                 0.843508           0.920080      0.861987
# Road of Return                      0.882814           0.940153      0.896652
# Storm Crow                          0.821273           0.908725      0.842378
# Walking Sponge                      0.812400           0.823126      0.847279
#
# [5 rows x 18108 columns]

# %%
# now to test the recommender system
rec_df['Shock'].sort_values()[1:11]
# Out:
# name
# Tarfire                0.111477
# Magma Jet              0.250731
# Ember Hauler           0.250731
# Unyaro Bee Sting       0.258323
# Moonglove Extract      0.262957
# Orcish Vandal          0.265870
# Deadapult              0.275776
# Explosive Apparatus    0.282453
# Goblin Test Pilot      0.287948
# Crackling Triton       0.287948
# Name: Shock, dtype: float64

# %%
rec_df['Static Orb'].sort_values()[1:11]
# Out:
# name
# Winter Orb            0.305952
# Stoic Angel           0.418682
# Damping Field         0.499399
# Imi Statue            0.499399
# Dovin Baan            0.558457
# Stabilizer            0.588946
# Castle Raptors        0.600509
# Armored Wolf-Rider    0.606081
# Royal Falcon          0.606081
# Alpha Myr             0.606081
# Name: Static Orb, dtype: float64

# %%
rec_df['Prized Amalgam'].sort_values()[1:11]
# Out:
# name
# Bone Dragon               0.438616
# Footsteps of the Goryo    0.477674
# Reassembling Skeleton     0.490087
# Despoiler of Souls        0.504859
# Scrapheap Scrounger       0.510044
# Ghoulsteed                0.512485
# Advanced Stitchwing       0.521772
# Stitchwing Skaab          0.539938
# Splendid Reclamation      0.544561
# Chronosavant              0.549436
# Name: Prized Amalgam, dtype: float64

# %%
rec_df['Wrath of God'].sort_values()[1:11]
# Out:
# name
# Damnation              1.110223e-16
# Perish                 2.111065e-01
# Winds of Rath          2.232762e-01
# Plague Wind            2.358599e-01
# Day of Judgment        2.524550e-01
# Extinguish All Hope    2.951452e-01
# Soulscour              3.071714e-01
# Plague Spores          3.124761e-01
# Plasma Elemental       3.134562e-01
# Final Judgment         3.134562e-01
# Name: Wrath of God, dtype: float64

# %%
rec_df['Jace, the Mind Sculptor'].sort_values()[1:11]
# Out:
# name
# Brainstorm                0.450524
# Riverwise Augur           0.454100
# Coral Fighters            0.461954
# Dream Cache               0.524370
# Eye Spy                   0.525424
# Voyage's End              0.528485
# Cavalier of Gales         0.530216
# Precognition              0.555188
# Stormcaller of Keranos    0.568001
# Watchful Automaton        0.568001
# Name: Jace, the Mind Sculptor, dtype: float64

# %% [markdown]
# ___

# %% [markdown]
# ## Non-numerical data
# Now I have to convert the non-numerical data into numerical data

# %%
df.dtypes
# Out:
# name                       object
# layout                     object
# colors                     object
# color_identity             object
# mana_cost                  object
# cmc                       float64
# type_line                  object
# card_type                  object
# super_type                 object
# sub_type                   object
# oracle_text                object
# oracle_text_token          object
# legalities                 object
# rarity                     object
# power                      object
# toughness                  object
# loyalty                    object
# card_faces                 object
# activated_ability         float64
# triggered_ability         float64
# oracle_text_back           object
# oracle_text_back_token     object
# colors_back                object
# power_back                 object
# toughness_back             object
# loyalty_back               object
# card_type_back             object
# super_type_back            object
# sub_type_back              object
# mana_cost_back             object
# oracle_combined            object
# dtype: object

# %% [markdown]
# ### colors

# %%
df = df.set_index(df['name']).drop(columns='name')

# %%
# essentially makeing dummy variables for colors and color identity
# I'm going to repeat this method for other columns as well
wburg = ['B', 'G', 'R', 'U', 'W']
for index in converted_df.index:
    for color in range(len(wburg)):
        converted_df.loc[index, 'colors_' + wburg[color]] = (wburg[color] in df.loc[index, 'colors']) * 1
        converted_df.loc[index, 'color_identity_' + wburg[color]] = (wburg[color] in df.loc[index, 'color_identity']) * 1

# %% [markdown]
# ### card type

# %%
card_types = ['Creature', 'Instant', 'Enchantment', 'Sorcery', 'Artifact', 'Land', 'Planeswalker', 'Tribal']
for index in converted_df.index:
    for ctype in range(len(card_types)):
        converted_df.loc[index, 'card_type_' + card_types[ctype]] = (card_types[ctype] in df.loc[index, 'card_type']) * 1

# %% [markdown]
# ### subtype

# %%
df['sub_type'].value_counts()
# Out:
# NONE                     6786
# Aura                      840
# Human Wizard              364
# Spirit                    309
# Human Soldier             300
#                          ...
# Cephalid Wizard Scout       1
# Zombie Satyr                1
# Oyster                      1
# Satyr Beast                 1
# Frog Mutant                 1
# Name: sub_type, Length: 1193, dtype: int64

# %% [markdown]
# ### super_type

# %%
df['super_type'].value_counts()
# Out:
# NONE              16915
# Legendary          1112
# Snow                 57
# World                16
# Basic                 6
# Legendary Snow        2
# Name: super_type, dtype: int64

# %% [markdown]
# ### legalities

# %%
df['legalities'].value_counts()
# Out:
# modern legacy vintage penny commander duel                                3040
# modern legacy pauper vintage penny commander duel                         2309
# legacy vintage commander duel                                             2168
# pioneer modern legacy vintage penny commander duel                        1820
# pioneer modern legacy pauper vintage penny commander duel                 1449
#                                                                           ...
# pioneer modern legacy commander duel                                         1
# historic modern legacy vintage penny commander duel                          1
# standard future historic pioneer modern legacy vintage commander brawl       1
# pioneer modern legacy vintage duel                                           1
# legacy commander duel                                                        1
# Name: legalities, Length: 66, dtype: int64

# %% [markdown]
# ### rarity

# %%
df['rarity'].value_counts()
# Out:
# common      6566
# uncommon    5631
# rare        5114
# mythic       797
# Name: rarity, dtype: int64

# %% [markdown]
# ### power

# %%
df['power'].value_counts()
# Out:
# NONE    8357
# 2       3038
# 1       2140
# 3       1796
# 4       1019
# 5        603
# 0        457
# 6        331
# 7        123
# *        119
# 8         56
# 10        23
# 9         23
# 12         7
# 11         5
# 13         3
# 1+*        3
# 15         2
# -1         2
# 16         1
# Name: power, dtype: int64

# %% [markdown]
# ### toughness

# %%
df['toughness'].value_counts()
# Out:
# NONE    8357
# 2       2557
# 1       2333
# 3       1964
# 4       1311
# 5        691
# 6        366
# 0        151
# 7        138
# *        103
# 8         62
# 9         24
# 10        22
# 11         7
# 12         7
# 13         5
# 1+*        5
# 15         2
# 16         1
# 14         1
# -1         1
# Name: toughness, dtype: int64

# %% [markdown]
# ### loyalty

# %%
df['loyalty'].value_counts()
# Out:
# NONE    17919
# 5          64
# 4          62
# 3          42
# 6           9
# 7           7
# 2           4
# X           1
# Name: loyalty, dtype: int64
