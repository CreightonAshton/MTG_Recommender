# %%
import pandas as pd

# %%
cards_df = pd.read_csv('../Data/converted_df.csv', index_col='name')

# %%
cards_df.head()
# Out:
#                      +0/+1  +0/+1 until  +0/+1 until end  +0/+1 until end of  \
# name
# Static Orb               0            0                0                   0
# Sensory Deprivation      0            0                0                   0
# Road of Return           0            0                0                   0
# Storm Crow               0            0                0                   0
# Walking Sponge           0            0                0                   0
#
#                      +0/+1 until end of turn  +0/+2  +0/+3  +1  +1/+0  \
# name
# Static Orb                                 0      0      0   0      0
# Sensory Deprivation                        0      0      0   0      0
# Road of Return                             0      0      0   0      0
# Storm Crow                                 0      0      0   0      0
# Walking Sponge                             0      0      0   0      0
#
# ...

# %%
cards_df.shape
# Out:
# (18098, 15592)

# %%
cards_df['power']
# Out:
# name
# Static Orb                 0.000000
# Sensory Deprivation        0.000000
# Road of Return             0.000000
# Storm Crow                -0.901216
# Walking Sponge            -0.901216
#                              ...
# Devoted Hero              -0.901216
# Without Weakness           0.000000
# Firesong and Sunspeaker    0.868362
# Samut, the Tested          0.000000
# Sinew Sliver              -0.901216
# Name: power, Length: 18098, dtype: float64
