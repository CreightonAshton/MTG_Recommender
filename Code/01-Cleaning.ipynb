# %% [markdown]
# # Magic: the Gathering Recommender System
# ___

# %% [markdown]
# ##### Problem Statement:
# I will use data on Magic: the Gathering cards to build a content-based recommender system that suggests similar cards in order to improve card selection during the deck building process.

# %% [markdown]
# ##### Outline:
# 1. Gathering Data
#     a. The data can be gathered from Scryfall's bulk data section which has every card as a json file
# 2. Cleaning Data
#     a. There is a lot of unnecessary data that I can drop
#     b. Extract the nested json objects
# 3. EDA
# 4. Recommender System
#     a. Content-Based Recommender
#     b. Cosine similarity
# 5. Stretch Goals
#     a. Keep a running tally and rating system for a user-based collaborative recommender

# %% [markdown]
# ##### Risks and Assumptions:
# One risk is that the data comes in the form of nested json objects which will need to be formatted in a way I can use it.
# I am also limiting the scope of the data to only look at unique cards. It can be a stretch goal to take into account any alternate printings
# Another potential issue is dealing with how the recommender system will actually recommend cards. For example, if a user enters 'Prized Amalgam' will they be recommended other 3 mana 3/3s in U/B or will/should it recommend cards that would work well with 'Prized Amalgam' like 'Bloodghast' or 'Narcomeba'

# %% [markdown]
# ##### Data Sources:
# [Scryfall Bulk Data](https://scryfall.com/docs/api/bulk-data)
# [Scryfall Oracle Cards](https://archive.scryfall.com/json/scryfall-oracle-cards.json)

# %% [markdown]
# ## 01 - Cleaning
# ___

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

from nltk.tokenize import RegexpTokenizer

pd.options.display.max_columns = 35

# %%
df = pd.read_json('../Data/scryfall-oracle-cards.json')

# %%
df.head()
# Out:
#   object                                    id  \
# 0   card  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012
# 1   card  7050735c-b232-47a6-a342-01795bfd0d46
# 2   card  e718b21b-46d1-4844-985c-52745657b1ac
# 3   card  036ef8c9-72ac-46ce-af07-83b79d736538
# 4   card  b125d1e7-5d9b-4997-88b0-71bdfc19c6f2
#
#                               oracle_id multiverse_ids  mtgo_id  mtgo_foil_id  \
# 0  0004ebd0-dfd6-4276-b4a6-de0003e94237        [15862]  15870.0       15871.0
# 1  0006faf6-7a61-426c-9034-579f2cfcfa83       [370780]  49283.0       49284.0
# 2  0007c283-5b7a-4c00-9ca1-b455c8dff8c3       [470580]  77122.0           NaN
# 3  000d5588-5a4c-434e-988d-396632ade42c        [83282]  22609.0       22610.0
# 4  000e5d65-96c3-498b-bd01-72b1a1991850        [12380]  12637.0       12638.0
#
#    tcgplayer_id                 name lang released_at  \
# 0        3094.0           Static Orb   en  2001-04-11
# 1       69965.0  Sensory Deprivation   en  2013-07-19
# 2      196536.0       Road of Return   en  2019-08-23
# 3       12835.0           Storm Crow   en  2005-07-29
# 4        6412.0       Walking Sponge   en  1999-02-15
#
#                                                  uri  \
# 0  https://api.scryfall.com/cards/86bf43b1-8d4e-4...
# 1  https://api.scryfall.com/cards/7050735c-b232-4...
# 2  https://api.scryfall.com/cards/e718b21b-46d1-4...
# 3  https://api.scryfall.com/cards/036ef8c9-72ac-4...
# 4  https://api.scryfall.com/cards/b125d1e7-5d9b-4...
#
#                                         scryfall_uri  layout  highres_image  \
# 0  https://scryfall.com/card/7ed/319/static-orb?u...  normal           True
# 1  https://scryfall.com/card/m14/71/sensory-depri...  normal           True
# 2  https://scryfall.com/card/c19/34/road-of-retur...  normal           True
# 3  https://scryfall.com/card/9ed/100/storm-crow?u...  normal           True
# 4  https://scryfall.com/card/ulg/47/walking-spong...  normal           True
#
#                                           image_uris mana_cost  cmc  ...  \
# 0  {'small': 'https://img.scryfall.com/cards/smal...       {3}  3.0  ...
# 1  {'small': 'https://img.scryfall.com/cards/smal...       {U}  1.0  ...
# 2  {'small': 'https://img.scryfall.com/cards/smal...    {G}{G}  2.0  ...
# 3  {'small': 'https://img.scryfall.com/cards/smal...    {1}{U}  2.0  ...
# 4  {'small': 'https://img.scryfall.com/cards/smal...    {1}{U}  2.0  ...
#
#   story_spotlight edhrec_rank  \
# 0           False      1660.0
# 1           False     17172.0
# 2           False      5184.0
# 3           False     10016.0
# 4           False     15762.0
#
#                                         related_uris  \
# 0  {'gatherer': 'https://gatherer.wizards.com/Pag...
# 1  {'gatherer': 'https://gatherer.wizards.com/Pag...
# 2  {'gatherer': 'https://gatherer.wizards.com/Pag...
# 3  {'gatherer': 'https://gatherer.wizards.com/Pag...
# 4  {'gatherer': 'https://gatherer.wizards.com/Pag...
#
#                                              preview power toughness  \
# 0                                                NaN   NaN       NaN
# 1                                                NaN   NaN       NaN
# 2  {'source': 'Magicshibby', 'source_uri': 'https...   NaN       NaN
# 3                                                NaN     1         2
# 4                                                NaN     1         1
#
#    arena_id  watermark  promo_types  all_parts  frame_effects  card_faces  \
# 0       NaN        NaN          NaN        NaN            NaN         NaN
# 1       NaN        NaN          NaN        NaN            NaN         NaN
# 2       NaN        NaN          NaN        NaN            NaN         NaN
# 3       NaN        NaN          NaN        NaN            NaN         NaN
# 4       NaN        NaN          NaN        NaN            NaN         NaN
#
#    life_modifier hand_modifier loyalty color_indicator variation_of
# 0            NaN           NaN     NaN             NaN          NaN
# 1            NaN           NaN     NaN             NaN          NaN
# 2            NaN           NaN     NaN             NaN          NaN
# 3            NaN           NaN     NaN             NaN          NaN
# 4            NaN           NaN     NaN             NaN          NaN
#
# [5 rows x 68 columns]

# %%
df.shape
# Out:
# (20782, 68)

# %%
df.columns
# Out:
# Index(['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id',
#        'mtgo_foil_id', 'tcgplayer_id', 'name', 'lang', 'released_at', 'uri',
#        'scryfall_uri', 'layout', 'highres_image', 'image_uris', 'mana_cost',
#        'cmc', 'type_line', 'oracle_text', 'colors', 'color_identity',
#        'legalities', 'games', 'reserved', 'foil', 'nonfoil', 'oversized',
#        'promo', 'reprint', 'variation', 'set', 'set_name', 'set_type',
#        'set_uri', 'set_search_uri', 'scryfall_set_uri', 'rulings_uri',
#        'prints_search_uri', 'collector_number', 'digital', 'rarity',
#        'flavor_text', 'card_back_id', 'artist', 'artist_ids',
#        'illustration_id', 'border_color', 'frame', 'full_art', 'textless',
#        'booster', 'story_spotlight', 'edhrec_rank', 'related_uris', 'preview',
#        'power', 'toughness', 'arena_id', 'watermark', 'promo_types',
#        'all_parts', 'frame_effects', 'card_faces', 'life_modifier',
#        'hand_modifier', 'loyalty', 'color_indicator', 'variation_of'],
#       dtype='object')

# %% [markdown]
# ___
# ### Drop unneeded columns

# %%
unneeded = ['id', 'oracle_id', 'multiverse_ids', 'tcgplayer_id', 'uri', 'scryfall_uri', 'image_uris', 
            'highres_image', 'games', 'set_uri', 'set_search_uri',  'scryfall_set_uri', 'rulings_uri', 
            'prints_search_uri', 'collector_number', 'card_back_id', 'artist_ids', 'illustration_id', 
            'story_spotlight', 'related_uris', 'preview', 'arena_id', 'all_parts', 'mtgo_id', 'variation_of',
            'color_indicator', 'mtgo_foil_id', 'life_modifier', 'hand_modifier', 'frame_effects', 'flavor_text',
            'watermark', 'lang', 'released_at', 'reserved', 'foil', 'nonfoil', 'promo', 'reprint', 'variation',
            'artist', 'frame', 'full_art', 'textless', 'booster', 'promo_types', 'edhrec_rank']
df = df.drop(columns=unneeded)

# %%
df.head()
# Out:
#   object                 name  layout mana_cost  cmc           type_line  \
# 0   card           Static Orb  normal       {3}  3.0            Artifact
# 1   card  Sensory Deprivation  normal       {U}  1.0  Enchantment — Aura
# 2   card       Road of Return  normal    {G}{G}  2.0             Sorcery
# 3   card           Storm Crow  normal    {1}{U}  2.0     Creature — Bird
# 4   card       Walking Sponge  normal    {1}{U}  2.0   Creature — Sponge
#
#                                          oracle_text colors color_identity  \
# 0  As long as Static Orb is untapped, players can...     []             []
# 1   Enchant creature\nEnchanted creature gets -3/-0.    [U]            [U]
# 2  Choose one —\n• Return target permanent card f...    [G]            [G]
# 3  Flying (This creature can't be blocked except ...    [U]            [U]
# 4  {T}: Target creature loses your choice of flyi...    [U]            [U]
#
#                                           legalities  oversized  set  \
# 0  {'standard': 'not_legal', 'future': 'not_legal...      False  7ed
# 1  {'standard': 'not_legal', 'future': 'not_legal...      False  m14
# 2  {'standard': 'not_legal', 'future': 'not_legal...      False  c19
# 3  {'standard': 'not_legal', 'future': 'not_legal...      False  9ed
# 4  {'standard': 'not_legal', 'future': 'not_legal...      False  ulg
#
#           set_name   set_type  digital    rarity border_color power toughness  \
# 0  Seventh Edition       core    False      rare        white   NaN       NaN
# 1       Magic 2014       core    False    common        black   NaN       NaN
# 2   Commander 2019  commander    False      rare        black   NaN       NaN
# 3    Ninth Edition       core    False    common        white     1         2
# 4    Urza's Legacy  expansion    False  uncommon        black     1         1
#
#   card_faces loyalty
# 0        NaN     NaN
# 1        NaN     NaN
# 2        NaN     NaN
# 3        NaN     NaN
# 4        NaN     NaN

# %%
df.columns
# Out:
# Index(['object', 'name', 'layout', 'mana_cost', 'cmc', 'type_line',
#        'oracle_text', 'colors', 'color_identity', 'legalities', 'oversized',
#        'set', 'set_name', 'set_type', 'digital', 'rarity', 'border_color',
#        'power', 'toughness', 'card_faces', 'loyalty'],
#       dtype='object')

# %% [markdown]
# I also want to drop any digital cards because I want the recommender to only look at physical cards

# %%
df = df.drop(df[df['digital'] == True].index)

# %% [markdown]
# Also drop oversized cards

# %%
df = df.drop(df[df['oversized'] == True].index)

# %%
df = df.drop(columns=['oversized', 'digital'])

# %% [markdown]
# ___
# ### check for nulls

# %%
df.isnull().sum()
# Out:
# object                0
# name                  0
# layout                0
# mana_cost           193
# cmc                   0
# type_line             0
# oracle_text         332
# colors              193
# color_identity        0
# legalities            0
# set                   0
# set_name              0
# set_type              0
# rarity                0
# border_color          0
# power              9074
# toughness          9074
# card_faces        19032
# loyalty           19169
# dtype: int64

# %%
df.shape
# Out:
# (19364, 19)

# %% [markdown]
# Art Series cards only existed in the modern horrizon set and are not actual cards, so we should drop them from our data set

# %%
df = df.drop(df[df['layout'] == 'art_series'].index)

# %%
# drop all the cards from the joke sets, because they are not legal in any format
df = df.drop(df[(df['set'] == 'unh') | (df['set'] == 'ugl') | (df['set'] == 'ust')].index)

# %%
df['border_color'].value_counts()
# Out:
# black         18076
# white           675
# gold             72
# silver           24
# borderless        1
# Name: border_color, dtype: int64

# %%
# drop any remaining gold or silver bordered cards because those are not legal either
df = df.drop(df.loc[(df['border_color'] == 'gold') | (df['border_color'] == 'silver')].index)

# %% [markdown]
# ### drop tokens and non-legal cards

# %%
df['layout'].value_counts()
# Out:
# normal                18034
# token                   345
# transform               104
# split                    86
# emblem                   51
# double_faced_token       33
# adventure                30
# leveler                  25
# flip                     20
# saga                     14
# meld                      9
# vanguard                  1
# Name: layout, dtype: int64

# %%
non_cards_index = df[(df['layout'] == 'double_faced_token') | (df['layout'] == 'token') | 
                             (df['layout'] == 'vanguard') | (df['layout'] == 'emblem')].index

# %%
df = df.drop(non_cards_index)
df = df.drop(df[df['set_type'] == 'token'].index)
df.shape
# Out:
# (18268, 19)

# %%
df['set_type'].value_counts()
# Out:
# expansion           10862
# funny                1819
# core                 1739
# commander            1316
# masters               900
# draft_innovation      609
# duel_deck             581
# starter               248
# planechase            100
# archenemy              79
# memorabilia            10
# box                     5
# Name: set_type, dtype: int64

# %%
df.loc[df['set_type'] == 'funny']['set'].value_counts()
# Out:
# mb1      1694
# cmb1      120
# htr17       3
# hho         2
# Name: set, dtype: int64

# %%
# the sets cmb1, htr17, and hho are not legal in any format so let's drop them
joke_cards_index = df.loc[(df['set'] == 'hho') | (df['set'] == 'htr17') | (df['set'] == 'cmb1')].index
df = df.drop(joke_cards_index)

# %%
# cards with the memorabilia set_type are also not legal in any format, so let's drop those as well.
non_legal_index = df.loc[df['set_type'] == 'memorabilia'].index
df = df.drop(non_legal_index)

# %%
# conspiracy cards are also not legal in any format
conspiracy_index = df.loc[df['type_line'] == 'Conspiracy'].index
df = df.drop(conspiracy_index)

# %%
# now that we've cleaned up the df a little, we can drop some more extraneous columns
df = df.drop(columns=['set', 'set_name', 'set_type', 'border_color'])

# %%
df.isnull().sum()
# Out:
# object                0
# name                  0
# layout                0
# mana_cost           104
# cmc                   0
# type_line             0
# oracle_text         237
# colors              104
# color_identity        0
# legalities            0
# rarity                0
# power              8436
# toughness          8436
# card_faces        17871
# loyalty           17921
# dtype: int64

# %%
df[df['colors'].isnull()]['layout'].value_counts()
# Out:
# transform    104
# Name: layout, dtype: int64

# %%
df[df['mana_cost'].isnull()]['layout'].value_counts()
# Out:
# transform    104
# Name: layout, dtype: int64

# %%
df[df['oracle_text'].isnull()]['layout'].value_counts()
# Out:
# transform    104
# split         83
# adventure     30
# flip          20
# Name: layout, dtype: int64

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#   object                 name  layout mana_cost  cmc           type_line  \
# 0   card           Static Orb  normal       {3}  3.0            Artifact
# 1   card  Sensory Deprivation  normal       {U}  1.0  Enchantment — Aura
# 2   card       Road of Return  normal    {G}{G}  2.0             Sorcery
# 3   card           Storm Crow  normal    {1}{U}  2.0     Creature — Bird
# 4   card       Walking Sponge  normal    {1}{U}  2.0   Creature — Sponge
#
#                                          oracle_text colors color_identity  \
# 0  As long as Static Orb is untapped, players can...     []             []
# 1   Enchant creature\nEnchanted creature gets -3/-0.    [U]            [U]
# 2  Choose one —\n• Return target permanent card f...    [G]            [G]
# 3  Flying (This creature can't be blocked except ...    [U]            [U]
# 4  {T}: Target creature loses your choice of flyi...    [U]            [U]
#
#                                           legalities    rarity power  \
# 0  {'standard': 'not_legal', 'future': 'not_legal...      rare   NaN
# 1  {'standard': 'not_legal', 'future': 'not_legal...    common   NaN
# 2  {'standard': 'not_legal', 'future': 'not_legal...      rare   NaN
# 3  {'standard': 'not_legal', 'future': 'not_legal...    common     1
# 4  {'standard': 'not_legal', 'future': 'not_legal...  uncommon     1
#
#   toughness card_faces loyalty
# 0       NaN        NaN     NaN
# 1       NaN        NaN     NaN
# 2       NaN        NaN     NaN
# 3         2        NaN     NaN
# 4         1        NaN     NaN

# %% [markdown]
# ___
# From here I'd like to deal with the dual cards (transform, split, adventure, and flip cards).
#
# For flip and transform cards I want to keep the names the same because I want the recommender to recommend the whole card, not just one half of it.

# %% [markdown]
# First let's deal with the transform cards.
# Since transform cards can have different values on each side, I'm going to make another column that keeps track of the transformed side's values. For example, the entry for Delver of Secrets // Insectile Aberration will be one row however will have a power column that will be Delver of Secrets's power and another column that will be Insectile Aberration's power. Same thing for other values on the card

# %%
trans_df = df.loc[df['layout'] == 'transform']
trans_df.head()
# Out:
#     object                                               name     layout  \
# 193   card         Ulvenwald Captive // Ulvenwald Abomination  transform
# 381   card        Westvale Abbey // Ormendahl, Profane Prince  transform
# 603   card           Extricator of Sin // Extricator of Flesh  transform
# 783   card                      Treasure Map // Treasure Cove  transform
# 926   card  Ulrich of the Krallenhorde // Ulrich, Uncontes...  transform
#
#     mana_cost  cmc                                          type_line  \
# 193       NaN  2.0  Creature — Werewolf Horror // Creature — Eldra...
# 381       NaN  0.0                 Land // Legendary Creature — Demon
# 603       NaN  3.0  Creature — Human Cleric // Creature — Eldrazi ...
# 783       NaN  2.0                                   Artifact // Land
# 926       NaN  5.0  Legendary Creature — Human Werewolf // Legenda...
#
#     oracle_text colors color_identity  \
# 193         NaN    NaN            [G]
# 381         NaN    NaN            [B]
# 603         NaN    NaN            [W]
# 783         NaN    NaN             []
# 926         NaN    NaN         [G, R]
#
#                                             legalities    rarity power  \
# 193  {'standard': 'not_legal', 'future': 'not_legal...    common   NaN
# 381  {'standard': 'not_legal', 'future': 'not_legal...      rare   NaN
# 603  {'standard': 'not_legal', 'future': 'not_legal...  uncommon   NaN
# 783  {'standard': 'not_legal', 'future': 'not_legal...      rare   NaN
# 926  {'standard': 'not_legal', 'future': 'not_legal...    mythic   NaN
#
#     toughness                                         card_faces loyalty
# 193       NaN  [{'object': 'card_face', 'name': 'Ulvenwald Ca...     NaN
# 381       NaN  [{'object': 'card_face', 'name': 'Westvale Abb...     NaN
# 603       NaN  [{'object': 'card_face', 'name': 'Extricator o...     NaN
# 783       NaN  [{'object': 'card_face', 'name': 'Treasure Map...     NaN
# 926       NaN  [{'object': 'card_face', 'name': 'Ulrich of th...     NaN

# %%
# set up empty lists to fill
# first set of lists are for the front half
mana_cost_list = []
oracle_text_list = []
colors_list = []
power_list = []
toughness_list = []
loyalty_list = []
card_type_list = []

# second set of lists are for the back half. We don't need mana cost for transformed sides because they are treated
# as the same as the front side
oracle_text_back_list = []
colors_back_list = []
power_back_list = []
toughness_back_list = []
loyalty_back_list = []
card_type_back_list = []

# iterate through our list of transform cards
for index in trans_df.index:
    
    # Front half of the cards
    mana_cost_list.append(trans_df.loc[index, 'card_faces'][0]['mana_cost'])
    oracle_text_list.append(trans_df.loc[index, 'card_faces'][0]['oracle_text'])
    colors_list.append(trans_df.loc[index, 'card_faces'][0]['colors'])
    # doing some try/excepts becuase not all cards have power, toughness, or loyalty
    try:
        power_list.append(trans_df.loc[index, 'card_faces'][0]['power'])
    except:
        power_list.append('NONE')
    try:
        toughness_list.append(trans_df.loc[index, 'card_faces'][0]['toughness'])
    except:
        toughness_list.append('NONE')
    try:
        loyalty_list.append(trans_df.loc[index, 'card_faces'][0]['loyalty'])
    except:
        loyalty_list.append('NONE')
    card_type_list.append(trans_df.loc[index, 'card_faces'][0]['type_line'].split(' — ')[0])
    
    # Back half of the cards
    oracle_text_back_list.append(trans_df.loc[index, 'card_faces'][1]['oracle_text'])
    colors_back_list.append(trans_df.loc[index, 'card_faces'][1]['colors'])
    try:
        power_back_list.append(trans_df.loc[index, 'card_faces'][1]['power'])
    except:
        power_back_list.append('NONE')
    try:
        toughness_back_list.append(trans_df.loc[index, 'card_faces'][1]['toughness'])
    except:
        toughness_back_list.append('NONE')
    try:
        loyalty_back_list.append(trans_df.loc[index, 'card_faces'][1]['loyalty'])
    except:
        loyalty_back_list.append('NONE')
    card_type_back_list.append(trans_df.loc[index, 'card_faces'][1]['type_line'].split(' — ')[0])
    
# fill in our values for the front half
df.loc[trans_df.index, 'mana_cost'] = mana_cost_list
df.loc[trans_df.index, 'oracle_text'] = oracle_text_list
df.loc[trans_df.index, 'colors'] = colors_list
df.loc[trans_df.index, 'power'] = power_list
df.loc[trans_df.index, 'toughness'] = toughness_list
df.loc[trans_df.index, 'loyalty'] = loyalty_list
df.loc[trans_df.index, 'card_type'] = card_type_list

# fill in our values for the back half
df.loc[trans_df.index, 'oracle_text_back'] = oracle_text_back_list
df.loc[trans_df.index, 'colors_back'] = colors_back_list
df.loc[trans_df.index, 'power_back'] = power_back_list
df.loc[trans_df.index, 'toughness_back'] = toughness_back_list
df.loc[trans_df.index, 'loyalty_back'] = loyalty_back_list
df.loc[trans_df.index, 'card_type_back'] = card_type_back_list

# %%
df.loc[trans_df.index].head()
# Out:
#     object                                               name     layout  \
# 193   card         Ulvenwald Captive // Ulvenwald Abomination  transform
# 381   card        Westvale Abbey // Ormendahl, Profane Prince  transform
# 603   card           Extricator of Sin // Extricator of Flesh  transform
# 783   card                      Treasure Map // Treasure Cove  transform
# 926   card  Ulrich of the Krallenhorde // Ulrich, Uncontes...  transform
#
#      mana_cost  cmc                                          type_line  \
# 193     {1}{G}  2.0  Creature — Werewolf Horror // Creature — Eldra...
# 381             0.0                 Land // Legendary Creature — Demon
# 603     {2}{W}  3.0  Creature — Human Cleric // Creature — Eldrazi ...
# 783        {2}  2.0                                   Artifact // Land
# 926  {3}{R}{G}  5.0  Legendary Creature — Human Werewolf // Legenda...
#
#                                            oracle_text  colors color_identity  \
# 193  Defender\n{T}: Add {G}.\n{5}{G}{G}: Transform ...     [G]            [G]
# 381  {T}: Add {C}.\n{5}, {T}, Pay 1 life: Create a ...      []            [B]
# 603  When Extricator of Sin enters the battlefield,...     [W]            [W]
# 783  {1}, {T}: Scry 1. Put a landmark counter on Tr...      []             []
# 926  Whenever this creature enters the battlefield ...  [G, R]         [G, R]
#
#                                             legalities    rarity power  \
# 193  {'standard': 'not_legal', 'future': 'not_legal...    common     1
# 381  {'standard': 'not_legal', 'future': 'not_legal...      rare  NONE
# 603  {'standard': 'not_legal', 'future': 'not_legal...  uncommon     0
# 783  {'standard': 'not_legal', 'future': 'not_legal...      rare  NONE
# 926  {'standard': 'not_legal', 'future': 'not_legal...    mythic     4
#
#     toughness                                         card_faces loyalty  \
# 193         2  [{'object': 'card_face', 'name': 'Ulvenwald Ca...    NONE
# 381      NONE  [{'object': 'card_face', 'name': 'Westvale Abb...    NONE
# 603         3  [{'object': 'card_face', 'name': 'Extricator o...    NONE
# 783      NONE  [{'object': 'card_face', 'name': 'Treasure Map...    NONE
# 926         4  [{'object': 'card_face', 'name': 'Ulrich of th...    NONE
#
#               card_type                                   oracle_text_back  \
# 193            Creature                                   {T}: Add {C}{C}.
# 381                Land            Flying, lifelink, indestructible, haste
# 603            Creature  Eldrazi you control have vigilance.\n{2}, {T},...
# 783            Artifact  (Transforms from Treasure Map.)\n{T}: Add {C}....
# 926  Legendary Creature  Whenever this creature transforms into Ulrich,...
#
#     colors_back power_back toughness_back loyalty_back      card_type_back
# 193          []          4              6         NONE            Creature
# 381         [B]          9              7         NONE  Legendary Creature
# 603          []          3              5         NONE            Creature
# 783          []       NONE           NONE         NONE                Land
# 926      [G, R]          6              6         NONE  Legendary Creature

# %% [markdown]
# Next let's deal with flip cards

# %%
flip_df = df.loc[df['layout'] == 'flip'].copy()
flip_df.head()
# Out:
#      object                                            name layout  mana_cost  \
# 1387   card  Nezumi Graverobber // Nighteyes the Desecrator   flip     {1}{B}
# 2459   card     Faithful Squire // Kaiso, Memory of Loyalty   flip  {1}{W}{W}
# 2979   card         Jushi Apprentice // Tomoya the Revealer   flip     {1}{U}
# 4274   card  Cunning Bandit // Azamuki, Treachery Incarnate   flip  {1}{R}{R}
# 4897   card      Nezumi Shortfang // Stabwhisker the Odious   flip     {1}{B}
#
#       cmc                                          type_line oracle_text  \
# 1387  2.0  Creature — Rat Rogue // Legendary Creature — R...         NaN
# 2459  3.0  Creature — Human Soldier // Legendary Creature...         NaN
# 2979  2.0  Creature — Human Wizard // Legendary Creature ...         NaN
# 4274  3.0  Creature — Human Warrior // Legendary Creature...         NaN
# 4897  2.0  Creature — Rat Rogue // Legendary Creature — R...         NaN
#
#      colors color_identity                                         legalities  \
# 1387    [B]            [B]  {'standard': 'not_legal', 'future': 'not_legal...
# 2459    [W]            [W]  {'standard': 'not_legal', 'future': 'not_legal...
# 2979    [U]            [U]  {'standard': 'not_legal', 'future': 'not_legal...
# 4274    [R]            [R]  {'standard': 'not_legal', 'future': 'not_legal...
# 4897    [B]            [B]  {'standard': 'not_legal', 'future': 'not_legal...
#
#         rarity power toughness  \
# 1387  uncommon     2         1
# 2459  uncommon     2         2
# 2979      rare     1         2
# 4274  uncommon     2         2
# 4897      rare     1         1
#
#                                              card_faces loyalty card_type  \
# 1387  [{'object': 'card_face', 'name': 'Nezumi Grave...     NaN       NaN
# 2459  [{'object': 'card_face', 'name': 'Faithful Squ...     NaN       NaN
# 2979  [{'object': 'card_face', 'name': 'Jushi Appren...     NaN       NaN
# 4274  [{'object': 'card_face', 'name': 'Cunning Band...     NaN       NaN
# 4897  [{'object': 'card_face', 'name': 'Nezumi Short...     NaN       NaN
#
#      oracle_text_back colors_back power_back toughness_back loyalty_back  \
# 1387              NaN         NaN        NaN            NaN          NaN
# 2459              NaN         NaN        NaN            NaN          NaN
# 2979              NaN         NaN        NaN            NaN          NaN
# 4274              NaN         NaN        NaN            NaN          NaN
# 4897              NaN         NaN        NaN            NaN          NaN
#
#      card_type_back
# 1387            NaN
# 2459            NaN
# 2979            NaN
# 4274            NaN
# 4897            NaN

# %%
# set up empty lists to fill
# first set of lists are for the front half
oracle_text_list = []
power_list = []
toughness_list = []
card_type_list = []

# second set of lists are for the back half. We don't need mana cost for transformed sides because they are treated
# as the same as the front side
oracle_text_back_list = []
power_back_list = []
toughness_back_list = []
card_type_back_list = []

# iterate through our list of transform cards
for index in flip_df.index:
    
    # Front half of the cards
    oracle_text_list.append(flip_df.loc[index, 'card_faces'][0]['oracle_text'])
    # doing some try/excepts becuase not all cards have power, toughness, or loyalty
    try:
        power_list.append(flip_df.loc[index, 'card_faces'][0]['power'])
    except:
        power_list.append('NONE')
    try:
        toughness_list.append(flip_df.loc[index, 'card_faces'][0]['toughness'])
    except:
        toughness_list.append('NONE')
    card_type_list.append(flip_df.loc[index, 'card_faces'][0]['type_line'].split(' — ')[0])
    
    # Back half of the cards
    oracle_text_back_list.append(flip_df.loc[index, 'card_faces'][1]['oracle_text'])
    try:
        power_back_list.append(flip_df.loc[index, 'card_faces'][1]['power'])
    except:
        power_back_list.append('NONE')
    try:
        toughness_back_list.append(flip_df.loc[index, 'card_faces'][1]['toughness'])
    except:
        toughness_back_list.append('NONE')
    card_type_back_list.append(flip_df.loc[index, 'card_faces'][1]['type_line'].split(' — ')[0])
    
# fill in our values for the front half
df.loc[flip_df.index, 'oracle_text'] = oracle_text_list
df.loc[flip_df.index, 'power'] = power_list
df.loc[flip_df.index, 'toughness'] = toughness_list
df.loc[flip_df.index, 'card_type'] = card_type_list

# fill in our values for the back half
df.loc[flip_df.index, 'oracle_text_back'] = oracle_text_back_list
df.loc[flip_df.index, 'power_back'] = power_back_list
df.loc[flip_df.index, 'toughness_back'] = toughness_back_list
df.loc[flip_df.index, 'card_type_back'] = card_type_back_list

# %%
df.loc[flip_df.index].head()
# Out:
#      object                                            name layout  mana_cost  \
# 1387   card  Nezumi Graverobber // Nighteyes the Desecrator   flip     {1}{B}
# 2459   card     Faithful Squire // Kaiso, Memory of Loyalty   flip  {1}{W}{W}
# 2979   card         Jushi Apprentice // Tomoya the Revealer   flip     {1}{U}
# 4274   card  Cunning Bandit // Azamuki, Treachery Incarnate   flip  {1}{R}{R}
# 4897   card      Nezumi Shortfang // Stabwhisker the Odious   flip     {1}{B}
#
#       cmc                                          type_line  \
# 1387  2.0  Creature — Rat Rogue // Legendary Creature — R...
# 2459  3.0  Creature — Human Soldier // Legendary Creature...
# 2979  2.0  Creature — Human Wizard // Legendary Creature ...
# 4274  3.0  Creature — Human Warrior // Legendary Creature...
# 4897  2.0  Creature — Rat Rogue // Legendary Creature — R...
#
#                                             oracle_text colors color_identity  \
# 1387  {1}{B}: Exile target card from an opponent's g...    [B]            [B]
# 2459  Whenever you cast a Spirit or Arcane spell, yo...    [W]            [W]
# 2979  {2}{U}, {T}: Draw a card. If you have nine or ...    [U]            [U]
# 4274  Whenever you cast a Spirit or Arcane spell, yo...    [R]            [R]
# 4897  {1}{B}, {T}: Target opponent discards a card. ...    [B]            [B]
#
#                                              legalities    rarity power  \
# 1387  {'standard': 'not_legal', 'future': 'not_legal...  uncommon     2
# 2459  {'standard': 'not_legal', 'future': 'not_legal...  uncommon     2
# 2979  {'standard': 'not_legal', 'future': 'not_legal...      rare     1
# 4274  {'standard': 'not_legal', 'future': 'not_legal...  uncommon     2
# 4897  {'standard': 'not_legal', 'future': 'not_legal...      rare     1
#
#      toughness                                         card_faces loyalty  \
# 1387         1  [{'object': 'card_face', 'name': 'Nezumi Grave...     NaN
# 2459         2  [{'object': 'card_face', 'name': 'Faithful Squ...     NaN
# 2979         2  [{'object': 'card_face', 'name': 'Jushi Appren...     NaN
# 4274         2  [{'object': 'card_face', 'name': 'Cunning Band...     NaN
# 4897         1  [{'object': 'card_face', 'name': 'Nezumi Short...     NaN
#
#      card_type                                   oracle_text_back colors_back  \
# 1387  Creature  {4}{B}: Put target creature card from a gravey...         NaN
# 2459  Creature  Flying\nRemove a ki counter from Kaiso, Memory...         NaN
# 2979  Creature  {3}{U}{U}, {T}: Target player draws X cards, w...         NaN
# 4274  Creature  Remove a ki counter from Azamuki, Treachery In...         NaN
# 4897  Creature  At the beginning of each opponent's upkeep, th...         NaN
#
#      power_back toughness_back loyalty_back      card_type_back
# 1387          4              2          NaN  Legendary Creature
# 2459          3              4          NaN  Legendary Creature
# 2979          2              3          NaN  Legendary Creature
# 4274          5              2          NaN  Legendary Creature
# 4897          3              3          NaN  Legendary Creature

# %% [markdown]
# Next, let's deal with the adventure cards.
# Adventure cards are different from flip and transform cards in that you could play either half of the card and not the other. However, in terms of cleaning we'll treat them the same

# %%
adv_df = df.loc[df['layout'] == 'adventure'].copy()
adv_df.head()
# Out:
#      object                                   name     layout  \
# 384    card  Faerie Guidemother // Gift of the Fae  adventure
# 629    card        Tuinvale Treefolk // Oaken Boon  adventure
# 1172   card           Murderous Rider // Swift End  adventure
# 1201   card     Foulmire Knight // Profane Insight  adventure
# 1259   card     Smitten Swordmaster // Curry Favor  adventure
#
#                    mana_cost  cmc  \
# 384            {W} // {1}{W}  1.0
# 629         {5}{G} // {3}{G}  6.0
# 1172  {1}{B}{B} // {1}{B}{B}  3.0
# 1201           {B} // {2}{B}  1.0
# 1259           {1}{B} // {B}  2.0
#
#                                              type_line oracle_text colors  \
# 384           Creature — Faerie // Sorcery — Adventure         NaN    [W]
# 629   Creature — Treefolk Druid // Sorcery — Adventure         NaN    [G]
# 1172   Creature — Zombie Knight // Instant — Adventure         NaN    [B]
# 1201   Creature — Zombie Knight // Instant — Adventure         NaN    [B]
# 1259    Creature — Human Knight // Sorcery — Adventure         NaN    [B]
#
#      color_identity                                         legalities  \
# 384             [W]  {'standard': 'legal', 'future': 'legal', 'hist...
# 629             [G]  {'standard': 'legal', 'future': 'legal', 'hist...
# 1172            [B]  {'standard': 'legal', 'future': 'legal', 'hist...
# 1201            [B]  {'standard': 'legal', 'future': 'legal', 'hist...
# 1259            [B]  {'standard': 'legal', 'future': 'legal', 'hist...
#
#         rarity power toughness  \
# 384     common     1         1
# 629     common     6         5
# 1172      rare     2         3
# 1201  uncommon     1         1
# 1259    common     2         1
#
#                                              card_faces loyalty card_type  \
# 384   [{'object': 'card_face', 'name': 'Faerie Guide...     NaN       NaN
# 629   [{'object': 'card_face', 'name': 'Tuinvale Tre...     NaN       NaN
# 1172  [{'object': 'card_face', 'name': 'Murderous Ri...     NaN       NaN
# 1201  [{'object': 'card_face', 'name': 'Foulmire Kni...     NaN       NaN
# 1259  [{'object': 'card_face', 'name': 'Smitten Swor...     NaN       NaN
#
#      oracle_text_back colors_back power_back toughness_back loyalty_back  \
# 384               NaN         NaN        NaN            NaN          NaN
# 629               NaN         NaN        NaN            NaN          NaN
# 1172              NaN         NaN        NaN            NaN          NaN
# 1201              NaN         NaN        NaN            NaN          NaN
# 1259              NaN         NaN        NaN            NaN          NaN
#
#      card_type_back
# 384             NaN
# 629             NaN
# 1172            NaN
# 1201            NaN
# 1259            NaN

# %%
# set up empty lists to fill
# first set of lists are for the creature half
mana_cost_list = []
oracle_text_list = []
power_list = []
toughness_list = []
card_type_list = []

# second set of lists are for the adventure half
oracle_text_back_list = []
card_type_back_list = []
mana_cost_back_list = []

# iterate through our list of adventure cards
for index in adv_df.index:
    
    # creature half of the cards
    mana_cost_list.append(adv_df.loc[index, 'card_faces'][0]['mana_cost'])
    oracle_text_list.append(adv_df.loc[index, 'card_faces'][0]['oracle_text'])
    power_list.append(adv_df.loc[index, 'card_faces'][0]['power'])
    toughness_list.append(adv_df.loc[index, 'card_faces'][0]['toughness'])
    card_type_list.append(adv_df.loc[index, 'card_faces'][0]['type_line'].split(' — ')[0])
    
    # adventure half of the cards
    mana_cost_back_list.append(adv_df.loc[index, 'card_faces'][1]['mana_cost'])
    oracle_text_back_list.append(adv_df.loc[index, 'card_faces'][1]['oracle_text'])
    card_type_back_list.append(adv_df.loc[index, 'card_faces'][1]['type_line'].split(' — ')[0])
    
# fill in our values for the creature half
df.loc[adv_df.index, 'mana_cost'] = mana_cost_list
df.loc[adv_df.index, 'oracle_text'] = oracle_text_list
df.loc[adv_df.index, 'power'] = power_list
df.loc[adv_df.index, 'toughness'] = toughness_list
df.loc[adv_df.index, 'card_type'] = card_type_list

# fill in our values for the adventure half
df.loc[adv_df.index, 'mana_cost_back'] = mana_cost_back_list
df.loc[adv_df.index, 'oracle_text_back'] = oracle_text_back_list
df.loc[adv_df.index, 'card_type_back'] = card_type_back_list

# %%
df.loc[adv_df.index].head()
# Out:
#      object                                   name     layout  mana_cost  cmc  \
# 384    card  Faerie Guidemother // Gift of the Fae  adventure        {W}  1.0
# 629    card        Tuinvale Treefolk // Oaken Boon  adventure     {5}{G}  6.0
# 1172   card           Murderous Rider // Swift End  adventure  {1}{B}{B}  3.0
# 1201   card     Foulmire Knight // Profane Insight  adventure        {B}  1.0
# 1259   card     Smitten Swordmaster // Curry Favor  adventure     {1}{B}  2.0
#
#                                              type_line  \
# 384           Creature — Faerie // Sorcery — Adventure
# 629   Creature — Treefolk Druid // Sorcery — Adventure
# 1172   Creature — Zombie Knight // Instant — Adventure
# 1201   Creature — Zombie Knight // Instant — Adventure
# 1259    Creature — Human Knight // Sorcery — Adventure
#
#                                             oracle_text colors color_identity  \
# 384                                              Flying    [W]            [W]
# 629                                                        [G]            [G]
# 1172  Lifelink\nWhen Murderous Rider dies, put it on...    [B]            [B]
# 1201                                         Deathtouch    [B]            [B]
# 1259                                           Lifelink    [B]            [B]
#
#                                              legalities    rarity power  \
# 384   {'standard': 'legal', 'future': 'legal', 'hist...    common     1
# 629   {'standard': 'legal', 'future': 'legal', 'hist...    common     6
# 1172  {'standard': 'legal', 'future': 'legal', 'hist...      rare     2
# 1201  {'standard': 'legal', 'future': 'legal', 'hist...  uncommon     1
# 1259  {'standard': 'legal', 'future': 'legal', 'hist...    common     2
#
#      toughness                                         card_faces loyalty  \
# 384          1  [{'object': 'card_face', 'name': 'Faerie Guide...     NaN
# 629          5  [{'object': 'card_face', 'name': 'Tuinvale Tre...     NaN
# 1172         3  [{'object': 'card_face', 'name': 'Murderous Ri...     NaN
# 1201         1  [{'object': 'card_face', 'name': 'Foulmire Kni...     NaN
# 1259         1  [{'object': 'card_face', 'name': 'Smitten Swor...     NaN
#
#      card_type                                   oracle_text_back colors_back  \
# 384   Creature  Target creature gets +2/+1 and gains flying un...         NaN
# 629   Creature  Put two +1/+1 counters on target creature. (Th...         NaN
# 1172  Creature  Destroy target creature or planeswalker. You l...         NaN
# 1201  Creature  You draw a card and you lose 1 life. (Then exi...         NaN
# 1259  Creature  You gain X life and each opponent loses X life...         NaN
#
#      power_back toughness_back loyalty_back card_type_back mana_cost_back
# 384         NaN            NaN          NaN        Sorcery         {1}{W}
# 629         NaN            NaN          NaN        Sorcery         {3}{G}
# 1172        NaN            NaN          NaN        Instant      {1}{B}{B}
# 1201        NaN            NaN          NaN        Instant         {2}{B}
# 1259        NaN            NaN          NaN        Sorcery            {B}

# %% [markdown]
# Finally, we'll deal with the split cards

# %%
split_df = df.loc[df['layout'] == 'split'].copy()
split_df.head()
# Out:
#     object                  name layout                mana_cost  cmc  \
# 297   card       Heaven // Earth  split      {X}{G} // {X}{R}{R}  3.0
# 322   card  Breaking // Entering  split      {U}{B} // {4}{B}{R}  8.0
# 526   card        Flesh // Blood  split      {3}{B}{G} // {R}{G}  7.0
# 583   card    Assure // Assemble  split  {G/W}{G/W} // {4}{G}{W}  8.0
# 770   card   Struggle // Survive  split         {2}{R} // {1}{G}  5.0
#
#               type_line oracle_text     colors color_identity  \
# 297  Instant // Sorcery         NaN     [G, R]         [G, R]
# 322  Sorcery // Sorcery         NaN  [B, R, U]      [B, R, U]
# 526  Sorcery // Sorcery         NaN  [B, G, R]      [B, G, R]
# 583  Instant // Instant         NaN     [G, W]         [G, W]
# 770  Instant // Sorcery         NaN     [G, R]         [G, R]
#
#                                             legalities    rarity power  \
# 297  {'standard': 'not_legal', 'future': 'not_legal...      rare   NaN
# 322  {'standard': 'not_legal', 'future': 'not_legal...      rare   NaN
# 526  {'standard': 'not_legal', 'future': 'not_legal...      rare   NaN
# 583  {'standard': 'legal', 'future': 'legal', 'hist...      rare   NaN
# 770  {'standard': 'not_legal', 'future': 'not_legal...  uncommon   NaN
#
#     toughness                                         card_faces loyalty  \
# 297       NaN  [{'object': 'card_face', 'name': 'Heaven', 'ma...     NaN
# 322       NaN  [{'object': 'card_face', 'name': 'Breaking', '...     NaN
# 526       NaN  [{'object': 'card_face', 'name': 'Flesh', 'man...     NaN
# 583       NaN  [{'object': 'card_face', 'name': 'Assure', 'ma...     NaN
# 770       NaN  [{'object': 'card_face', 'name': 'Struggle', '...     NaN
#
#     card_type oracle_text_back colors_back power_back toughness_back  \
# 297       NaN              NaN         NaN        NaN            NaN
# 322       NaN              NaN         NaN        NaN            NaN
# 526       NaN              NaN         NaN        NaN            NaN
# 583       NaN              NaN         NaN        NaN            NaN
# 770       NaN              NaN         NaN        NaN            NaN
#
#     loyalty_back card_type_back mana_cost_back
# 297          NaN            NaN            NaN
# 322          NaN            NaN            NaN
# 526          NaN            NaN            NaN
# 583          NaN            NaN            NaN
# 770          NaN            NaN            NaN

# %%
# set up empty lists to fill
# first set of lists are for the front half
mana_cost_list = []
oracle_text_list = []
card_type_list = []

# second set of lists are for the back half.
mana_cost_back_list = []
oracle_text_back_list = []
card_type_back_list = []

# iterate through our list of transform cards
for index in split_df.index:
    
    # Front half of the cards
    mana_cost_list.append(split_df.loc[index, 'card_faces'][0]['mana_cost'])
    oracle_text_list.append(split_df.loc[index, 'card_faces'][0]['oracle_text'])
    card_type_list.append(split_df.loc[index, 'card_faces'][0]['type_line'].split(' — ')[0])
    
    # Back half of the cards
    mana_cost_back_list.append(split_df.loc[index, 'card_faces'][1]['mana_cost'])
    oracle_text_back_list.append(split_df.loc[index, 'card_faces'][1]['oracle_text'])
    card_type_back_list.append(split_df.loc[index, 'card_faces'][1]['type_line'].split(' — ')[0])
    
# fill in our values for the front half
df.loc[split_df.index, 'mana_cost'] = mana_cost_list
df.loc[split_df.index, 'oracle_text'] = oracle_text_list
df.loc[split_df.index, 'card_type'] = card_type_list

# fill in our values for the back half
df.loc[split_df.index, 'mana_cost_back'] = mana_cost_back_list
df.loc[split_df.index, 'oracle_text_back'] = oracle_text_back_list
df.loc[split_df.index, 'card_type_back'] = card_type_back_list

# %%
df.loc[split_df.index].head()
# Out:
#     object                  name layout   mana_cost  cmc           type_line  \
# 297   card       Heaven // Earth  split      {X}{G}  3.0  Instant // Sorcery
# 322   card  Breaking // Entering  split      {U}{B}  8.0  Sorcery // Sorcery
# 526   card        Flesh // Blood  split   {3}{B}{G}  7.0  Sorcery // Sorcery
# 583   card    Assure // Assemble  split  {G/W}{G/W}  8.0  Instant // Instant
# 770   card   Struggle // Survive  split      {2}{R}  5.0  Instant // Sorcery
#
#                                            oracle_text     colors  \
# 297  Heaven deals X damage to each creature with fl...     [G, R]
# 322  Target player puts the top eight cards of thei...  [B, R, U]
# 526  Exile target creature card from a graveyard. P...  [B, G, R]
# 583  Put a +1/+1 counter on target creature. That c...     [G, W]
# 770  Struggle deals damage to target creature equal...     [G, R]
#
#     color_identity                                         legalities  \
# 297         [G, R]  {'standard': 'not_legal', 'future': 'not_legal...
# 322      [B, R, U]  {'standard': 'not_legal', 'future': 'not_legal...
# 526      [B, G, R]  {'standard': 'not_legal', 'future': 'not_legal...
# 583         [G, W]  {'standard': 'legal', 'future': 'legal', 'hist...
# 770         [G, R]  {'standard': 'not_legal', 'future': 'not_legal...
#
#        rarity power toughness  \
# 297      rare   NaN       NaN
# 322      rare   NaN       NaN
# 526      rare   NaN       NaN
# 583      rare   NaN       NaN
# 770  uncommon   NaN       NaN
#
#                                             card_faces loyalty card_type  \
# 297  [{'object': 'card_face', 'name': 'Heaven', 'ma...     NaN   Instant
# 322  [{'object': 'card_face', 'name': 'Breaking', '...     NaN   Sorcery
# 526  [{'object': 'card_face', 'name': 'Flesh', 'man...     NaN   Sorcery
# 583  [{'object': 'card_face', 'name': 'Assure', 'ma...     NaN   Instant
# 770  [{'object': 'card_face', 'name': 'Struggle', '...     NaN   Instant
#
#                                       oracle_text_back colors_back power_back  \
# 297  Aftermath (Cast this spell only from your grav...         NaN        NaN
# 322  Put a creature card from a graveyard onto the ...         NaN        NaN
# 526  Target creature you control deals damage equal...         NaN        NaN
# 583  Create three 2/2 green and white Elf Knight cr...         NaN        NaN
# 770  Aftermath (Cast this spell only from your grav...         NaN        NaN
#
#     toughness_back loyalty_back card_type_back mana_cost_back
# 297            NaN          NaN        Sorcery      {X}{R}{R}
# 322            NaN          NaN        Sorcery      {4}{B}{R}
# 526            NaN          NaN        Sorcery         {R}{G}
# 583            NaN          NaN        Instant      {4}{G}{W}
# 770            NaN          NaN        Sorcery         {1}{G}

# %%
df.isnull().sum()
# Out:
# object                  0
# name                    0
# layout                  0
# mana_cost               0
# cmc                     0
# type_line               0
# oracle_text             0
# colors                  0
# color_identity          0
# legalities              0
# rarity                  0
# power                8332
# toughness            8332
# card_faces          17871
# loyalty             17817
# card_type           17871
# oracle_text_back    17871
# colors_back         18004
# power_back          17984
# toughness_back      17984
# loyalty_back        18004
# card_type_back      17871
# mana_cost_back      17995
# dtype: int64

# %% [markdown]
# ___
# Let's get the card types from the type line

# %%
missing_card_type_index = df.loc[df['card_type'].isnull()].index

card_type_list = []

for index in missing_card_type_index:
    card_type_list.append(df.loc[index, 'type_line'].split(' — ')[0])
    
df.loc[missing_card_type_index, 'card_type'] = card_type_list

# %%
df['card_type'].value_counts()
# Out:
# Creature                          8286
# Instant                           2268
# Enchantment                       2044
# Sorcery                           1989
# Artifact                          1126
# Legendary Creature                 757
# Artifact Creature                  540
# Land                               532
# Legendary Planeswalker             189
# Enchantment Creature                69
# Legendary Artifact                  63
# Snow Creature                       37
# Legendary Land                      34
# Legendary Enchantment               30
# Tribal Instant                      20
# Legendary Enchantment Creature      16
# Tribal Sorcery                      16
# World Enchantment                   16
# Tribal Enchantment                  13
# Legendary Artifact Creature         12
# Snow Land                            8
# Basic Land                           6
# Legendary Sorcery                    6
# Artifact Land                        6
# Snow Enchantment                     6
# Tribal Artifact                      5
# Legendary Enchantment Artifact       5
# Snow Artifact Creature               4
# Snow Artifact                        2
# Land Creature                        1
# Legendary Snow Land                  1
# Legendary Snow Enchantment           1
# Name: card_type, dtype: int64

# %%
df.isnull().sum()
# Out:
# object                  0
# name                    0
# layout                  0
# mana_cost               0
# cmc                     0
# type_line               0
# oracle_text             0
# colors                  0
# color_identity          0
# legalities              0
# rarity                  0
# power                8332
# toughness            8332
# card_faces          17871
# loyalty             17817
# card_type               0
# oracle_text_back    17871
# colors_back         18004
# power_back          17984
# toughness_back      17984
# loyalty_back        18004
# card_type_back      17871
# mana_cost_back      17995
# dtype: int64

# %%
df.loc[df['power'].isnull()]['card_type'].value_counts()
# Out:
# Instant                           2268
# Enchantment                       2042
# Sorcery                           1988
# Artifact                          1094
# Land                               531
# Legendary Planeswalker             187
# Legendary Artifact                  57
# Legendary Land                      34
# Tribal Instant                      20
# Legendary Enchantment               20
# World Enchantment                   16
# Tribal Sorcery                      16
# Tribal Enchantment                  13
# Snow Land                            8
# Artifact Land                        6
# Legendary Sorcery                    6
# Snow Enchantment                     6
# Basic Land                           6
# Legendary Enchantment Artifact       5
# Tribal Artifact                      5
# Snow Artifact                        2
# Legendary Snow Enchantment           1
# Legendary Snow Land                  1
# Name: card_type, dtype: int64

# %%
# The rest of the Nulls in the power and toughness columns are non-creatures so they don't have a power or
# toughness. We will impute those nulls as 'NONE'
df['power'] = df['power'].fillna('NONE')
df['toughness'] = df['toughness'].fillna('NONE')
df.isnull().sum()
# Out:
# object                  0
# name                    0
# layout                  0
# mana_cost               0
# cmc                     0
# type_line               0
# oracle_text             0
# colors                  0
# color_identity          0
# legalities              0
# rarity                  0
# power                   0
# toughness               0
# card_faces          17871
# loyalty             17817
# card_type               0
# oracle_text_back    17871
# colors_back         18004
# power_back          17984
# toughness_back      17984
# loyalty_back        18004
# card_type_back      17871
# mana_cost_back      17995
# dtype: int64

# %%
df.loc[df['card_faces'].isnull()]['layout'].value_counts()
# Out:
# normal     17823
# leveler       25
# saga          14
# meld           9
# Name: layout, dtype: int64

# %%
# the rest of the Nulls for card_faces are for non-dual-cards, so let's impute those Nulls as 'NONE'
df['card_faces'] = df['card_faces'].fillna('NONE')

# %%
df.loc[df['loyalty'].isnull()]['card_type'].value_counts()
# Out:
# Creature                          8219
# Instant                           2268
# Enchantment                       2042
# Sorcery                           1988
# Artifact                          1118
# Legendary Creature                 749
# Artifact Creature                  537
# Land                               531
# Enchantment Creature                69
# Legendary Artifact                  61
# Snow Creature                       37
# Legendary Land                      34
# Tribal Instant                      20
# Legendary Enchantment               20
# Tribal Sorcery                      16
# Legendary Enchantment Creature      16
# World Enchantment                   16
# Tribal Enchantment                  13
# Legendary Artifact Creature         12
# Snow Land                            8
# Basic Land                           6
# Snow Enchantment                     6
# Legendary Sorcery                    6
# Artifact Land                        6
# Tribal Artifact                      5
# Legendary Enchantment Artifact       5
# Snow Artifact Creature               4
# Snow Artifact                        2
# Land Creature                        1
# Legendary Snow Enchantment           1
# Legendary Snow Land                  1
# Name: card_type, dtype: int64

# %%
# the Nulls for loyalty are for non-planeswalker cards, so fill those Nulls as 'NONE'
df['loyalty'] = df['loyalty'].fillna('NONE')

# %%
# The rest of the Nulls are for back half of cards that are non-dual cards, so let's impute those as 'NONE'
df = df.fillna('NONE')
df.isnull().sum()
# Out:
# object              0
# name                0
# layout              0
# mana_cost           0
# cmc                 0
# type_line           0
# oracle_text         0
# colors              0
# color_identity      0
# legalities          0
# rarity              0
# power               0
# toughness           0
# card_faces          0
# loyalty             0
# card_type           0
# oracle_text_back    0
# colors_back         0
# power_back          0
# toughness_back      0
# loyalty_back        0
# card_type_back      0
# mana_cost_back      0
# dtype: int64

# %%
df.loc[(df['mana_cost'] == "")]['card_type'].value_counts()
# Out:
# Land                   532
# Legendary Land          34
# Snow Land                8
# Artifact Land            6
# Basic Land               6
# Sorcery                  6
# Artifact                 2
# Legendary Creature       2
# Land Creature            1
# Instant                  1
# Creature                 1
# Legendary Snow Land      1
# Name: card_type, dtype: int64

# %%
# these mana costs should be None to avoid Null values later on
# according to the rules of magic no mana cost is different than a mana cost of {0}
no_mana_cost = df.loc[(df['mana_cost'] == "")].index
df.loc[no_mana_cost, 'mana_cost'] = 'NONE'

# %%
df.loc[no_mana_cost].head()
# Out:
#     object                       name  layout mana_cost  cmc       type_line  \
# 45    card  Shizo, Death's Storehouse  normal      NONE  0.0  Legendary Land
# 57    card               Timber Gorge  normal      NONE  0.0            Land
# 64    card                 Game Trail  normal      NONE  0.0            Land
# 69    card         Selesnya Sanctuary  normal      NONE  0.0            Land
# 116   card             Urborg Volcano  normal      NONE  0.0            Land
#
#                                            oracle_text colors color_identity  \
# 45   {T}: Add {B}.\n{B}, {T}: Target legendary crea...     []            [B]
# 57   Timber Gorge enters the battlefield tapped.\n{...     []         [G, R]
# 64   As Game Trail enters the battlefield, you may ...     []         [G, R]
# 69   Selesnya Sanctuary enters the battlefield tapp...     []         [G, W]
# 116  Urborg Volcano enters the battlefield tapped.\...     []         [B, R]
#
#                                             legalities    rarity power  \
# 45   {'standard': 'not_legal', 'future': 'not_legal...      rare  NONE
# 57   {'standard': 'not_legal', 'future': 'not_legal...    common  NONE
# 64   {'standard': 'not_legal', 'future': 'not_legal...      rare  NONE
# 69   {'standard': 'not_legal', 'future': 'not_legal...    common  NONE
# 116  {'standard': 'not_legal', 'future': 'not_legal...  uncommon  NONE
#
#     toughness card_faces loyalty       card_type oracle_text_back colors_back  \
# 45       NONE       NONE    NONE  Legendary Land             NONE        NONE
# 57       NONE       NONE    NONE            Land             NONE        NONE
# 64       NONE       NONE    NONE            Land             NONE        NONE
# 69       NONE       NONE    NONE            Land             NONE        NONE
# 116      NONE       NONE    NONE            Land             NONE        NONE
#
#     power_back toughness_back loyalty_back card_type_back mana_cost_back
# 45        NONE           NONE         NONE           NONE           NONE
# 57        NONE           NONE         NONE           NONE           NONE
# 64        NONE           NONE         NONE           NONE           NONE
# 69        NONE           NONE         NONE           NONE           NONE
# 116       NONE           NONE         NONE           NONE           NONE

# %%
# Any leftover blank oracle text entries are for vanilla creatures (meaning they have no abilities)
vanilla_creatures = df.loc[(df['oracle_text'] == "") | (df['oracle_text_back'] == "")].index

df.loc[vanilla_creatures, ['oracle_text', 'oracle_text_back']] = 'NONE'

df.loc[vanilla_creatures].head()
# Out:
#     object                  name  layout  mana_cost  cmc  \
# 25    card  Leopard-Spotted Jiao  normal     {1}{R}  2.0
# 38    card       Dakmor Scorpion  normal     {1}{B}  2.0
# 50    card           Scaled Wurm  normal     {7}{G}  8.0
# 102   card     Oreskos Swiftclaw  normal     {1}{W}  2.0
# 109   card  Minotaur Abomination  normal  {4}{B}{B}  6.0
#
#                       type_line oracle_text colors color_identity  \
# 25             Creature — Beast        NONE    [R]            [R]
# 38          Creature — Scorpion        NONE    [B]            [B]
# 50              Creature — Wurm        NONE    [G]            [G]
# 102      Creature — Cat Warrior        NONE    [W]            [W]
# 109  Creature — Zombie Minotaur        NONE    [B]            [B]
#
#                                             legalities  rarity power  \
# 25   {'standard': 'not_legal', 'future': 'not_legal...  common     3
# 38   {'standard': 'not_legal', 'future': 'not_legal...  common     2
# 50   {'standard': 'not_legal', 'future': 'not_legal...  common     7
# 102  {'standard': 'not_legal', 'future': 'not_legal...  common     3
# 109  {'standard': 'not_legal', 'future': 'not_legal...  common     4
#
#     toughness card_faces loyalty card_type oracle_text_back colors_back  \
# 25          1       NONE    NONE  Creature             NONE        NONE
# 38          1       NONE    NONE  Creature             NONE        NONE
# 50          6       NONE    NONE  Creature             NONE        NONE
# 102         1       NONE    NONE  Creature             NONE        NONE
# 109         6       NONE    NONE  Creature             NONE        NONE
#
#     power_back toughness_back loyalty_back card_type_back mana_cost_back
# 25        NONE           NONE         NONE           NONE           NONE
# 38        NONE           NONE         NONE           NONE           NONE
# 50        NONE           NONE         NONE           NONE           NONE
# 102       NONE           NONE         NONE           NONE           NONE
# 109       NONE           NONE         NONE           NONE           NONE

# %% [markdown]
# Now I'd like to break out the super-type of each card because by the rules of the game they are not considered to be card types. super-types include Basic, Legendary, Snow, and World

# %%
df.loc[df['card_type'] == 'Legendary Creature'].head()
# Out:
#     object                         name  layout     mana_cost  cmc  \
# 12    card   Hua Tuo, Honored Physician  normal     {1}{G}{G}  3.0
# 20    card  Kalitas, Bloodchief of Ghet  normal     {5}{B}{B}  7.0
# 51    card     Yorvo, Lord of Garenbrig  normal     {G}{G}{G}  3.0
# 85    card       Higure, the Still Wind  normal     {3}{U}{U}  5.0
# 124   card        Jareth, Leonine Titan  normal  {3}{W}{W}{W}  6.0
#
#                                 type_line  \
# 12             Legendary Creature — Human
# 20   Legendary Creature — Vampire Warrior
# 51       Legendary Creature — Giant Noble
# 85       Legendary Creature — Human Ninja
# 124        Legendary Creature — Cat Giant
#
#                                            oracle_text colors color_identity  \
# 12   {T}: Put target creature card from your gravey...    [G]            [G]
# 20   {B}{B}{B}, {T}: Destroy target creature. If th...    [B]            [B]
# 51   Yorvo, Lord of Garenbrig enters the battlefiel...    [G]            [G]
# 85   Ninjutsu {2}{U}{U} ({2}{U}{U}, Return an unblo...    [U]            [U]
# 124  Whenever Jareth, Leonine Titan blocks, it gets...    [W]            [W]
#
#                                             legalities  rarity power  \
# 12   {'standard': 'not_legal', 'future': 'not_legal...    rare     1
# 20   {'standard': 'not_legal', 'future': 'not_legal...  mythic     5
# 51   {'standard': 'legal', 'future': 'legal', 'hist...    rare     0
# 85   {'standard': 'not_legal', 'future': 'not_legal...    rare     3
# 124  {'standard': 'not_legal', 'future': 'not_legal...    rare     4
#
#     toughness card_faces loyalty           card_type oracle_text_back  \
# 12          2       NONE    NONE  Legendary Creature             NONE
# 20          5       NONE    NONE  Legendary Creature             NONE
# 51          0       NONE    NONE  Legendary Creature             NONE
# 85          4       NONE    NONE  Legendary Creature             NONE
# 124         7       NONE    NONE  Legendary Creature             NONE
#
#     colors_back power_back toughness_back loyalty_back card_type_back  \
# 12         NONE       NONE           NONE         NONE           NONE
# 20         NONE       NONE           NONE         NONE           NONE
# 51         NONE       NONE           NONE         NONE           NONE
# 85         NONE       NONE           NONE         NONE           NONE
# 124        NONE       NONE           NONE         NONE           NONE
#
#     mana_cost_back
# 12            NONE
# 20            NONE
# 51            NONE
# 85            NONE
# 124           NONE

# %%
super_types = ['Legendary', 'Snow', 'World', 'Basic']

for card in df.index:
    
    card_super_type_list = []
    card_super_type_list_back = []

    for word in df.loc[card, 'card_type'].split():

        if word in super_types:
            card_super_type_list.append(word)
    
    for word in df.loc[card, 'card_type_back'].split():

        if word in super_types:
            card_super_type_list_back.append(word)
            
    
    if card_super_type_list == []:
        card_super_type_list = ['NONE']
        
    if card_super_type_list_back == []:
        card_super_type_list_back = ['NONE']
        
    df.loc[card, 'super_type'] = " ".join(card_super_type_list)
    df.loc[card, 'super_type_back'] = " ".join(card_super_type_list_back)
           
df.head()
# Out:
#   object                 name  layout mana_cost  cmc           type_line  \
# 0   card           Static Orb  normal       {3}  3.0            Artifact
# 1   card  Sensory Deprivation  normal       {U}  1.0  Enchantment — Aura
# 2   card       Road of Return  normal    {G}{G}  2.0             Sorcery
# 3   card           Storm Crow  normal    {1}{U}  2.0     Creature — Bird
# 4   card       Walking Sponge  normal    {1}{U}  2.0   Creature — Sponge
#
#                                          oracle_text colors color_identity  \
# 0  As long as Static Orb is untapped, players can...     []             []
# 1   Enchant creature\nEnchanted creature gets -3/-0.    [U]            [U]
# 2  Choose one —\n• Return target permanent card f...    [G]            [G]
# 3  Flying (This creature can't be blocked except ...    [U]            [U]
# 4  {T}: Target creature loses your choice of flyi...    [U]            [U]
#
#                                           legalities    rarity power  \
# 0  {'standard': 'not_legal', 'future': 'not_legal...      rare  NONE
# 1  {'standard': 'not_legal', 'future': 'not_legal...    common  NONE
# 2  {'standard': 'not_legal', 'future': 'not_legal...      rare  NONE
# 3  {'standard': 'not_legal', 'future': 'not_legal...    common     1
# 4  {'standard': 'not_legal', 'future': 'not_legal...  uncommon     1
#
#   toughness card_faces loyalty    card_type oracle_text_back colors_back  \
# 0      NONE       NONE    NONE     Artifact             NONE        NONE
# 1      NONE       NONE    NONE  Enchantment             NONE        NONE
# 2      NONE       NONE    NONE      Sorcery             NONE        NONE
# 3         2       NONE    NONE     Creature             NONE        NONE
# 4         1       NONE    NONE     Creature             NONE        NONE
#
#   power_back toughness_back loyalty_back card_type_back mana_cost_back  \
# 0       NONE           NONE         NONE           NONE           NONE
# 1       NONE           NONE         NONE           NONE           NONE
# 2       NONE           NONE         NONE           NONE           NONE
# 3       NONE           NONE         NONE           NONE           NONE
# 4       NONE           NONE         NONE           NONE           NONE
#
#   super_type super_type_back
# 0       NONE            NONE
# 1       NONE            NONE
# 2       NONE            NONE
# 3       NONE            NONE
# 4       NONE            NONE

# %%
# now I'd like to remove the super_type from the card_type for each card
for index in df.loc[df['super_type'] != 'NONE'].index:
    df.loc[index, 'card_type'] = df.loc[index, 'card_type'].replace(df.loc[index, 'super_type'], '').strip()
    
# back half
for index in df.loc[df['super_type_back'] != 'NONE'].index:
    df.loc[index, 'card_type_back'] = df.loc[index, 'card_type_back'].replace(df.loc[index, 'super_type_back'], '').strip()

# %%
df['card_type'].value_counts()
# Out:
# Creature                9080
# Instant                 2268
# Enchantment             2097
# Sorcery                 1995
# Artifact                1191
# Land                     581
# Artifact Creature        556
# Planeswalker             189
# Enchantment Creature      85
# Tribal Instant            20
# Tribal Sorcery            16
# Tribal Enchantment        13
# Artifact Land              6
# Enchantment Artifact       5
# Tribal Artifact            5
# Land Creature              1
# Name: card_type, dtype: int64

# %%
df['card_type_back'].value_counts()
# Out:
# NONE                 17871
# Creature                88
# Sorcery                 69
# Instant                 44
# Land                    17
# Planeswalker             8
# Enchantment              7
# Artifact                 3
# Artifact Creature        1
# Name: card_type_back, dtype: int64

# %%
# this is to clean up the leaglities column a little
for index in df.index:
    legal_formats = []
    for form in df.loc[index, 'legalities']:
        if df.loc[index, 'legalities'][form] == 'legal':
            legal_formats.append(form)
    df.loc[index, 'legalities'] = " ".join(legal_formats)

# %%
# there are some other older cards that are not legal in any format, i.e. cards that refer to ante, so those 
# legalities need to be set to NONE to avoid Null values later.
non_legal_cards = df.loc[df['legalities'] == ""].index
df.loc[non_legal_cards, 'legalities'] = 'NONE'

# %%
df.head()
# Out:
#   object                 name  layout mana_cost  cmc           type_line  \
# 0   card           Static Orb  normal       {3}  3.0            Artifact
# 1   card  Sensory Deprivation  normal       {U}  1.0  Enchantment — Aura
# 2   card       Road of Return  normal    {G}{G}  2.0             Sorcery
# 3   card           Storm Crow  normal    {1}{U}  2.0     Creature — Bird
# 4   card       Walking Sponge  normal    {1}{U}  2.0   Creature — Sponge
#
#                                          oracle_text colors color_identity  \
# 0  As long as Static Orb is untapped, players can...     []             []
# 1   Enchant creature\nEnchanted creature gets -3/-0.    [U]            [U]
# 2  Choose one —\n• Return target permanent card f...    [G]            [G]
# 3  Flying (This creature can't be blocked except ...    [U]            [U]
# 4  {T}: Target creature loses your choice of flyi...    [U]            [U]
#
#                                           legalities    rarity power  \
# 0                      legacy vintage commander duel      rare  NONE
# 1  pioneer modern legacy pauper vintage penny com...    common  NONE
# 2                      legacy vintage commander duel      rare  NONE
# 3  modern legacy pauper vintage penny commander duel    common     1
# 4                      legacy vintage commander duel  uncommon     1
#
#   toughness card_faces loyalty    card_type oracle_text_back colors_back  \
# 0      NONE       NONE    NONE     Artifact             NONE        NONE
# 1      NONE       NONE    NONE  Enchantment             NONE        NONE
# 2      NONE       NONE    NONE      Sorcery             NONE        NONE
# 3         2       NONE    NONE     Creature             NONE        NONE
# 4         1       NONE    NONE     Creature             NONE        NONE
#
#   power_back toughness_back loyalty_back card_type_back mana_cost_back  \
# 0       NONE           NONE         NONE           NONE           NONE
# 1       NONE           NONE         NONE           NONE           NONE
# 2       NONE           NONE         NONE           NONE           NONE
# 3       NONE           NONE         NONE           NONE           NONE
# 4       NONE           NONE         NONE           NONE           NONE
#
#   super_type super_type_back
# 0       NONE            NONE
# 1       NONE            NONE
# 2       NONE            NONE
# 3       NONE            NONE
# 4       NONE            NONE

# %% [markdown]
# Now is a good time to also get the sub_type of a card.
# Sub_types include: Aura, Vehicle, Arcane, Equipment, etc.
# For creatures sub_types also include any further classifications i.e. human, elf, bird, etc.
# Planeswalkers also have a sub_type (with the exception of one card, The Wanderer) which are the name of the character i.e. Jace, Chandra, Oko, etc

# %%
for index in df.index:
    try:
        df.loc[index, 'sub_type'] = df.loc[index, 'type_line'].split(' // ')[0].split(' — ')[1]
    except:
        df.loc[index, 'sub_type'] = 'NONE'
    try:
        df.loc[index, 'sub_type_back'] = df.loc[index, 'type_line'].split(' // ')[1].split(' — ')[1]
    except:
        df.loc[index, 'sub_type_back'] = 'NONE'

# %%
df.head()
# Out:
#   object                 name  layout mana_cost  cmc           type_line  \
# 0   card           Static Orb  normal       {3}  3.0            Artifact
# 1   card  Sensory Deprivation  normal       {U}  1.0  Enchantment — Aura
# 2   card       Road of Return  normal    {G}{G}  2.0             Sorcery
# 3   card           Storm Crow  normal    {1}{U}  2.0     Creature — Bird
# 4   card       Walking Sponge  normal    {1}{U}  2.0   Creature — Sponge
#
#                                          oracle_text colors color_identity  \
# 0  As long as Static Orb is untapped, players can...     []             []
# 1   Enchant creature\nEnchanted creature gets -3/-0.    [U]            [U]
# 2  Choose one —\n• Return target permanent card f...    [G]            [G]
# 3  Flying (This creature can't be blocked except ...    [U]            [U]
# 4  {T}: Target creature loses your choice of flyi...    [U]            [U]
#
#                                           legalities    rarity power  \
# 0                      legacy vintage commander duel      rare  NONE
# 1  pioneer modern legacy pauper vintage penny com...    common  NONE
# 2                      legacy vintage commander duel      rare  NONE
# 3  modern legacy pauper vintage penny commander duel    common     1
# 4                      legacy vintage commander duel  uncommon     1
#
#   toughness card_faces loyalty    card_type oracle_text_back colors_back  \
# 0      NONE       NONE    NONE     Artifact             NONE        NONE
# 1      NONE       NONE    NONE  Enchantment             NONE        NONE
# 2      NONE       NONE    NONE      Sorcery             NONE        NONE
# 3         2       NONE    NONE     Creature             NONE        NONE
# 4         1       NONE    NONE     Creature             NONE        NONE
#
#   power_back toughness_back loyalty_back card_type_back mana_cost_back  \
# 0       NONE           NONE         NONE           NONE           NONE
# 1       NONE           NONE         NONE           NONE           NONE
# 2       NONE           NONE         NONE           NONE           NONE
# 3       NONE           NONE         NONE           NONE           NONE
# 4       NONE           NONE         NONE           NONE           NONE
#
#   super_type super_type_back sub_type sub_type_back
# 0       NONE            NONE     NONE          NONE
# 1       NONE            NONE     Aura          NONE
# 2       NONE            NONE     NONE          NONE
# 3       NONE            NONE     Bird          NONE
# 4       NONE            NONE   Sponge          NONE

# %%
df.columns
# Out:
# Index(['object', 'name', 'layout', 'mana_cost', 'cmc', 'type_line',
#        'oracle_text', 'colors', 'color_identity', 'legalities', 'rarity',
#        'power', 'toughness', 'card_faces', 'loyalty', 'card_type',
#        'oracle_text_back', 'colors_back', 'power_back', 'toughness_back',
#        'loyalty_back', 'card_type_back', 'mana_cost_back', 'super_type',
#        'super_type_back', 'sub_type', 'sub_type_back'],
#       dtype='object')

# %%
# reordering the columns
df = df[['name', 'layout', 'colors', 'color_identity', 'mana_cost', 'cmc', 'type_line', 'card_type', 'super_type', 
    'sub_type', 'oracle_text', 'legalities', 'rarity', 'power', 'toughness', 'loyalty', 'card_faces',
    'oracle_text_back', 'colors_back', 'power_back', 'toughness_back', 'loyalty_back', 'card_type_back',
    'super_type_back', 'sub_type_back', 'mana_cost_back'
   ]]

# %% [markdown]
# ___
# I'd like to make a column that denotes if a card has an acivated ability and another column if the card has a triggered ability. I did have these as seperate processes then later realized I can combine them to save on computing power. To further increase performance I could do cluster computing with scala, but that might not be worth the hassle and may not save time in the long run.

# %%
for index in df.index:
    # an acitvated ability on a card is denoted by a ':'
    if ':' in df.loc[index, 'oracle_text'] or ':' in df.loc[index, 'oracle_text_back']:
        df.loc[index, 'activated_ability'] = 1
    else:
        df.loc[index, 'activated_ability'] = 0

    # triggered abilities occur when certain conditions are met and use the keywords 'when', 'whenever', and 'at'
    if re.search(r'\bwhenever\b', df.loc[index, 'oracle_text'].lower()) != None or re.search(r'\bwhenever\b', df.loc[index, 'oracle_text_back'].lower()) != None:
        df.loc[index, 'triggered_ability'] = 1
    elif re.search(r'\bwhen\b', df.loc[index, 'oracle_text'].lower()) != None or re.search(r'\bwhen\b', df.loc[index, 'oracle_text_back'].lower()) != None:
        df.loc[index, 'triggered_ability'] = 1
    elif re.search(r'\bat\b', df.loc[index, 'oracle_text'].lower()) != None or re.search(r'\bat\b', df.loc[index, 'oracle_text_back'].lower()) != None:
        df.loc[index, 'triggered_ability'] = 1
    else:
        df.loc[index, 'triggered_ability'] = 0
        
    # While I'm at it, I want to git rid of all the '/n' from the oracle texts
    df.loc[index, 'oracle_text'] = df.loc[index, 'oracle_text'].replace('\n', ' ')
    df.loc[index, 'oracle_text_back'] = df.loc[index, 'oracle_text_back'].replace('\n', ' ')

# %% [markdown]
# ___

# %% [markdown]
# Now I need to clean up the oracle_text and oracle_text_back columns using RegEx

# %%
# # first we need to get rid of all the '\n'
# for index in df.index:
#     df.loc[index, 'oracle_text'] = df.loc[index, 'oracle_text'].replace('\n', ' ')
#     df.loc[index, 'oracle_text_back'] = df.loc[index, 'oracle_text_back'].replace('\n', ' ')

# %%
# instatiate the tokenizer
tknr = RegexpTokenizer(r"[a-zA-Z{}+'0-9-/−]+")

odf = df.loc[df['oracle_text'] != 'NONE']
obdf = df.loc[df['oracle_text_back'] != 'NONE']

# start with empty lists
tokens = []
tokens_back = []

# fill the lists with tokenized versions of each card's oracle_text
for card in odf['oracle_text']:
    tokens.append(" ".join(tknr.tokenize(card.lower())))

for card in obdf['oracle_text_back']:
    tokens_back.append(" ".join(tknr.tokenize(card.lower())))

# update the oracle_text columns
df.loc[odf.index, 'oracle_text_token'] = tokens
df.loc[obdf.index, 'oracle_text_back_token'] = tokens_back

# %%
# reordering the columns
df = df[['name', 'layout', 'colors', 'color_identity', 'mana_cost', 'cmc', 'type_line', 'card_type', 'super_type', 
    'sub_type', 'oracle_text', 'oracle_text_token', 'legalities', 'rarity', 'power', 'toughness', 'loyalty',
    'card_faces', 'activated_ability', 'triggered_ability', 'oracle_text_back', 'oracle_text_back_token',
    'colors_back', 'power_back', 'toughness_back', 'loyalty_back', 'card_type_back', 'super_type_back',
    'sub_type_back', 'mana_cost_back'
   ]]

df.fillna('NONE', inplace=True)

# %%
df.head()
# Out:
#                   name  layout colors color_identity mana_cost  cmc  \
# 0           Static Orb  normal     []             []       {3}  3.0
# 1  Sensory Deprivation  normal    [U]            [U]       {U}  1.0
# 2       Road of Return  normal    [G]            [G]    {G}{G}  2.0
# 3           Storm Crow  normal    [U]            [U]    {1}{U}  2.0
# 4       Walking Sponge  normal    [U]            [U]    {1}{U}  2.0
#
#             type_line    card_type super_type sub_type  \
# 0            Artifact     Artifact       NONE     NONE
# 1  Enchantment — Aura  Enchantment       NONE     Aura
# 2             Sorcery      Sorcery       NONE     NONE
# 3     Creature — Bird     Creature       NONE     Bird
# 4   Creature — Sponge     Creature       NONE   Sponge
#
#                                          oracle_text  \
# 0  As long as Static Orb is untapped, players can...
# 1    Enchant creature Enchanted creature gets -3/-0.
# 2  Choose one — • Return target permanent card fr...
# 3  Flying (This creature can't be blocked except ...
# 4  {T}: Target creature loses your choice of flyi...
#
#                                    oracle_text_token  \
# 0  as long as static orb is untapped players can'...
# 1     enchant creature enchanted creature gets -3/-0
# 2  choose one return target permanent card from y...
# 3  flying this creature can't be blocked except b...
# 4  {t} target creature loses your choice of flyin...
#
#                                           legalities    rarity power  \
# 0                      legacy vintage commander duel      rare  NONE
# 1  pioneer modern legacy pauper vintage penny com...    common  NONE
# 2                      legacy vintage commander duel      rare  NONE
# 3  modern legacy pauper vintage penny commander duel    common     1
# 4                      legacy vintage commander duel  uncommon     1
#
#   toughness loyalty card_faces  activated_ability  triggered_ability  \
# 0      NONE    NONE       NONE                0.0                0.0
# 1      NONE    NONE       NONE                0.0                0.0
# 2      NONE    NONE       NONE                0.0                0.0
# 3         2    NONE       NONE                0.0                0.0
# 4         1    NONE       NONE                1.0                0.0
#
#   oracle_text_back oracle_text_back_token colors_back power_back  \
# 0             NONE                   NONE        NONE       NONE
# 1             NONE                   NONE        NONE       NONE
# 2             NONE                   NONE        NONE       NONE
# 3             NONE                   NONE        NONE       NONE
# 4             NONE                   NONE        NONE       NONE
#
#   toughness_back loyalty_back card_type_back super_type_back sub_type_back  \
# 0           NONE         NONE           NONE            NONE          NONE
# 1           NONE         NONE           NONE            NONE          NONE
# 2           NONE         NONE           NONE            NONE          NONE
# 3           NONE         NONE           NONE            NONE          NONE
# 4           NONE         NONE           NONE            NONE          NONE
#
#   mana_cost_back
# 0           NONE
# 1           NONE
# 2           NONE
# 3           NONE
# 4           NONE

# %% [markdown]
# ___

# %%
# save out our cleaned df
df.to_csv('../Data/cards_cleaned.csv', index=False)
