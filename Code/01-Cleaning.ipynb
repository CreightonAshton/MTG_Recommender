# %% [markdown]
# # Magic: the Gathering Recommender System
# ___

# %% [markdown]
# ##### Problem Statement:
# I will use data on Magic: the Gathering cards to build a content-based recommender system that suggests similar cards in order to improve card selection during the deck building process.

# %% [markdown]
# ##### Outline:
# 1. Gathering Data
#     a. The data can be gathered from Scryfall's bulk data section which has every card as a json file
# 2. Cleaning Data
#     a. There is a lot of unnecessary data that I can drop
#     b. Extract the nested json objects
# 3. EDA
# 4. Recommender System
#     a. Content-Based Recommender
#     b. Cosine similarity
# 5. Stretch Goals
#     a. Keep a running tally and rating system for a user-based collaborative recommender

# %% [markdown]
# ##### Risks and Assumptions:
# One risk is that the data comes in the form of nested json objects which will need to be formatted in a way I can use it.
# I am also limiting the scope of the data to only look at unique cards. It can be a stretch goal to take into account any alternate printings
# Another potential issue is dealing with how the recommender system will actually recommend cards. For example, if a user enters 'Prized Amalgam' will they be recommended other 3 mana 3/3s in U/B or will/should it recommend cards that would work well with 'Prized Amalgam' like 'Bloodghast' or 'Narcomeba'

# %% [markdown]
# ##### Data Sources:
# [Scryfall Bulk Data](https://scryfall.com/docs/api/bulk-data)
# [Scryfall Oracle Cards](https://archive.scryfall.com/json/scryfall-oracle-cards.json)

# %% [markdown]
# ## 01 - Cleaning
# ___

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import matplotlib.pyplot as plt
import re

from nltk.tokenize import RegexpTokenizer

pd.options.display.max_columns = 35

# %%
df = pd.read_json('../Data/scryfall-oracle-cards.json')

# %%
df.head()
# Out:
#   object                                    id  \
# 0   card  86bf43b1-8d4e-4759-bb2d-0b2e03ba7012
# 1   card  7050735c-b232-47a6-a342-01795bfd0d46
# 2   card  e718b21b-46d1-4844-985c-52745657b1ac
# 3   card  036ef8c9-72ac-46ce-af07-83b79d736538
# 4   card  b125d1e7-5d9b-4997-88b0-71bdfc19c6f2
#
#                               oracle_id multiverse_ids  mtgo_id  mtgo_foil_id  \
# 0  0004ebd0-dfd6-4276-b4a6-de0003e94237        [15862]  15870.0       15871.0
# 1  0006faf6-7a61-426c-9034-579f2cfcfa83       [370780]  49283.0       49284.0
# 2  0007c283-5b7a-4c00-9ca1-b455c8dff8c3       [470580]  77122.0           NaN
# 3  000d5588-5a4c-434e-988d-396632ade42c        [83282]  22609.0       22610.0
# 4  000e5d65-96c3-498b-bd01-72b1a1991850        [12380]  12637.0       12638.0
#
#    tcgplayer_id                 name lang released_at  \
# 0        3094.0           Static Orb   en  2001-04-11
# 1       69965.0  Sensory Deprivation   en  2013-07-19
# 2      196536.0       Road of Return   en  2019-08-23
# 3       12835.0           Storm Crow   en  2005-07-29
# 4        6412.0       Walking Sponge   en  1999-02-15
#
#                                                  uri  \
# 0  https://api.scryfall.com/cards/86bf43b1-8d4e-4...
# 1  https://api.scryfall.com/cards/7050735c-b232-4...
# 2  https://api.scryfall.com/cards/e718b21b-46d1-4...
# 3  https://api.scryfall.com/cards/036ef8c9-72ac-4...
# 4  https://api.scryfall.com/cards/b125d1e7-5d9b-4...
#
#                                         scryfall_uri  layout  highres_image  \
# 0  https://scryfall.com/card/7ed/319/static-orb?u...  normal           True
# 1  https://scryfall.com/card/m14/71/sensory-depri...  normal           True
# 2  https://scryfall.com/card/c19/34/road-of-retur...  normal           True
# 3  https://scryfall.com/card/9ed/100/storm-crow?u...  normal           True
# 4  https://scryfall.com/card/ulg/47/walking-spong...  normal           True
#
#                                           image_uris mana_cost  cmc  ...  \
# 0  {'small': 'https://img.scryfall.com/cards/smal...       {3}  3.0  ...
# 1  {'small': 'https://img.scryfall.com/cards/smal...       {U}  1.0  ...
# 2  {'small': 'https://img.scryfall.com/cards/smal...    {G}{G}  2.0  ...
# 3  {'small': 'https://img.scryfall.com/cards/smal...    {1}{U}  2.0  ...
# 4  {'small': 'https://img.scryfall.com/cards/smal...    {1}{U}  2.0  ...
#
#   story_spotlight edhrec_rank  \
# 0           False      1682.0
# 1           False     17244.0
# 2           False      4924.0
# 3           False     10094.0
# 4           False     15848.0
#
#                                         related_uris  \
# 0  {'gatherer': 'https://gatherer.wizards.com/Pag...
# 1  {'gatherer': 'https://gatherer.wizards.com/Pag...
# 2  {'gatherer': 'https://gatherer.wizards.com/Pag...
# 3  {'gatherer': 'https://gatherer.wizards.com/Pag...
# 4  {'gatherer': 'https://gatherer.wizards.com/Pag...
#
#                                              preview power toughness  \
# 0                                                NaN   NaN       NaN
# 1                                                NaN   NaN       NaN
# 2  {'source': 'Magicshibby', 'source_uri': 'https...   NaN       NaN
# 3                                                NaN     1         2
# 4                                                NaN     1         1
#
#    arena_id  watermark  promo_types  all_parts  frame_effects  card_faces  \
# 0       NaN        NaN          NaN        NaN            NaN         NaN
# 1       NaN        NaN          NaN        NaN            NaN         NaN
# 2       NaN        NaN          NaN        NaN            NaN         NaN
# 3       NaN        NaN          NaN        NaN            NaN         NaN
# 4       NaN        NaN          NaN        NaN            NaN         NaN
#
#    life_modifier hand_modifier loyalty color_indicator variation_of
# 0            NaN           NaN     NaN             NaN          NaN
# 1            NaN           NaN     NaN             NaN          NaN
# 2            NaN           NaN     NaN             NaN          NaN
# 3            NaN           NaN     NaN             NaN          NaN
# 4            NaN           NaN     NaN             NaN          NaN
#
# [5 rows x 68 columns]

# %%
df.shape
# Out:
# (20784, 68)

# %%
df.columns
# Out:
# Index(['object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id',
#        'mtgo_foil_id', 'tcgplayer_id', 'name', 'lang', 'released_at', 'uri',
#        'scryfall_uri', 'layout', 'highres_image', 'image_uris', 'mana_cost',
#        'cmc', 'type_line', 'oracle_text', 'colors', 'color_identity',
#        'legalities', 'games', 'reserved', 'foil', 'nonfoil', 'oversized',
#        'promo', 'reprint', 'variation', 'set', 'set_name', 'set_type',
#        'set_uri', 'set_search_uri', 'scryfall_set_uri', 'rulings_uri',
#        'prints_search_uri', 'collector_number', 'digital', 'rarity',
#        'flavor_text', 'card_back_id', 'artist', 'artist_ids',
#        'illustration_id', 'border_color', 'frame', 'full_art', 'textless',
#        'booster', 'story_spotlight', 'edhrec_rank', 'related_uris', 'preview',
#        'power', 'toughness', 'arena_id', 'watermark', 'promo_types',
#        'all_parts', 'frame_effects', 'card_faces', 'life_modifier',
#        'hand_modifier', 'loyalty', 'color_indicator', 'variation_of'],
#       dtype='object')

# %%
df.loc[df['layout']=='transform'].head()
# Out:
#      object                                    id  \
# 220    card  0dbaef61-fa39-4ea7-bc21-445401c373e7
# 434    card  c1f53d7a-9dad-46e8-b686-cd1362867445
# 703    card  b6867ddd-f953-41c6-ba36-86ae2c14c908
# 903    card  c0f9c733-0818-4a03-8f0c-a163d09e0fff
# 1065   card  3e2011f0-a640-4579-bd67-1dfbc09b8c09
#
#                                  oracle_id    multiverse_ids  mtgo_id  \
# 220   0272ca81-e727-4f4b-b06e-072d70bb5558  [414479, 414480]  61462.0
# 434   04eeb9ad-5c59-411b-8809-db8349838588  [410049, 410050]  59810.0
# 703   08b3328c-1d96-4a05-ae8b-f1b654084faa  [414313, 414314]  61316.0
# 903   0b55eac6-a745-4bf4-8926-5ce83bc38d7d  [435410, 435411]  65528.0
# 1065  0d397c05-a680-4274-972f-6a5f778b5133  [414496, 414497]  61268.0
#
#       mtgo_foil_id  tcgplayer_id  \
# 220        61463.0      120122.0
# 434        59811.0      115917.0
# 703        61317.0      120485.0
# 903        65529.0      144537.0
# 1065       61269.0      119477.0
#
#                                                    name lang released_at  \
# 220          Ulvenwald Captive // Ulvenwald Abomination   en  2016-07-22
# 434         Westvale Abbey // Ormendahl, Profane Prince   en  2016-04-08
# 703            Extricator of Sin // Extricator of Flesh   en  2016-07-22
# 903                       Treasure Map // Treasure Cove   en  2017-09-29
# 1065  Ulrich of the Krallenhorde // Ulrich, Uncontes...   en  2016-07-22
#
#                                                     uri  \
# 220   https://api.scryfall.com/cards/0dbaef61-fa39-4...
# 434   https://api.scryfall.com/cards/c1f53d7a-9dad-4...
# 703   https://api.scryfall.com/cards/b6867ddd-f953-4...
# 903   https://api.scryfall.com/cards/c0f9c733-0818-4...
# 1065  https://api.scryfall.com/cards/3e2011f0-a640-4...
#
#                                            scryfall_uri     layout  \
# 220   https://scryfall.com/card/emn/175/ulvenwald-ca...  transform
# 434   https://scryfall.com/card/soi/281/westvale-abb...  transform
# 703   https://scryfall.com/card/emn/23/extricator-of...  transform
# 903   https://scryfall.com/card/xln/250/treasure-map...  transform
# 1065  https://scryfall.com/card/emn/191/ulrich-of-th...  transform
#
#       highres_image image_uris mana_cost  cmc  ... story_spotlight  \
# 220            True        NaN       NaN  2.0  ...           False
# 434            True        NaN       NaN  0.0  ...           False
# 703            True        NaN       NaN  3.0  ...           False
# 903            True        NaN       NaN  2.0  ...           False
# 1065           True        NaN       NaN  5.0  ...           False
#
#      edhrec_rank                                       related_uris preview  \
# 220       4669.0  {'gatherer': 'https://gatherer.wizards.com/Pag...     NaN
# 434        367.0  {'gatherer': 'https://gatherer.wizards.com/Pag...     NaN
# 703      11092.0  {'gatherer': 'https://gatherer.wizards.com/Pag...     NaN
# 903       1446.0  {'gatherer': 'https://gatherer.wizards.com/Pag...     NaN
# 1065      5405.0  {'gatherer': 'https://gatherer.wizards.com/Pag...     NaN
#
#      power toughness  arena_id  watermark  promo_types  \
# 220    NaN       NaN       NaN        NaN          NaN
# 434    NaN       NaN       NaN        NaN          NaN
# 703    NaN       NaN       NaN        NaN          NaN
# 903    NaN       NaN   66477.0        NaN          NaN
# 1065   NaN       NaN       NaN        NaN          NaN
#
#                                               all_parts     frame_effects  \
# 220                                                 NaN  [mooneldrazidfc]
# 434   [{'object': 'related_card', 'id': 'c1f53d7a-9d...      [sunmoondfc]
# 703   [{'object': 'related_card', 'id': 'b6867ddd-f9...  [mooneldrazidfc]
# 903   [{'object': 'related_card', 'id': 'c0f9c733-08...  [compasslanddfc]
# 1065                                                NaN      [sunmoondfc]
#
#                                              card_faces  life_modifier  \
# 220   [{'object': 'card_face', 'name': 'Ulvenwald Ca...            NaN
# 434   [{'object': 'card_face', 'name': 'Westvale Abb...            NaN
# 703   [{'object': 'card_face', 'name': 'Extricator o...            NaN
# 903   [{'object': 'card_face', 'name': 'Treasure Map...            NaN
# 1065  [{'object': 'card_face', 'name': 'Ulrich of th...            NaN
#
#      hand_modifier loyalty color_indicator variation_of
# 220            NaN     NaN             NaN          NaN
# 434            NaN     NaN             NaN          NaN
# 703            NaN     NaN             NaN          NaN
# 903            NaN     NaN             NaN          NaN
# 1065           NaN     NaN             NaN          NaN
#
# [5 rows x 68 columns]

# %%
df.loc[220, 'scryfall_uri']
# Out:
# 'https://scryfall.com/card/emn/175/ulvenwald-captive-ulvenwald-abomination?utm_source=api'

# %% [markdown]
# ___
# ### Drop unneeded columns

# %%
unneeded = ['id', 'oracle_id', 'multiverse_ids', 'tcgplayer_id', 'uri', 'image_uris',
            'highres_image', 'games', 'set_uri', 'set_search_uri',  'scryfall_set_uri', 'rulings_uri', 
            'prints_search_uri', 'collector_number', 'card_back_id', 'artist_ids', 'illustration_id', 
            'story_spotlight', 'related_uris', 'preview', 'arena_id', 'all_parts', 'mtgo_id', 'variation_of',
            'color_indicator', 'mtgo_foil_id', 'life_modifier', 'hand_modifier', 'frame_effects', 'flavor_text',
            'watermark', 'lang', 'released_at', 'reserved', 'foil', 'nonfoil', 'promo', 'reprint', 'variation',
            'artist', 'frame', 'full_art', 'textless', 'booster', 'promo_types', 'edhrec_rank']
df = df.drop(columns=unneeded)

# %%
df.head()
# Out:
#   object                 name  \
# 0   card           Static Orb
# 1   card  Sensory Deprivation
# 2   card       Road of Return
# 3   card           Storm Crow
# 4   card       Walking Sponge
#
#                                         scryfall_uri  layout mana_cost  cmc  \
# 0  https://scryfall.com/card/7ed/319/static-orb?u...  normal       {3}  3.0
# 1  https://scryfall.com/card/m14/71/sensory-depri...  normal       {U}  1.0
# 2  https://scryfall.com/card/c19/34/road-of-retur...  normal    {G}{G}  2.0
# 3  https://scryfall.com/card/9ed/100/storm-crow?u...  normal    {1}{U}  2.0
# 4  https://scryfall.com/card/ulg/47/walking-spong...  normal    {1}{U}  2.0
#
#             type_line                                        oracle_text  \
# 0            Artifact  As long as Static Orb is untapped, players can...
# 1  Enchantment — Aura   Enchant creature\nEnchanted creature gets -3/-0.
# 2             Sorcery  Choose one —\n• Return target permanent card f...
# 3     Creature — Bird  Flying (This creature can't be blocked except ...
# 4   Creature — Sponge  {T}: Target creature loses your choice of flyi...
#
#   colors color_identity                                         legalities  \
# 0     []             []  {'standard': 'not_legal', 'future': 'not_legal...
# 1    [U]            [U]  {'standard': 'not_legal', 'future': 'not_legal...
# 2    [G]            [G]  {'standard': 'not_legal', 'future': 'not_legal...
# 3    [U]            [U]  {'standard': 'not_legal', 'future': 'not_legal...
# 4    [U]            [U]  {'standard': 'not_legal', 'future': 'not_legal...
#
#    oversized  set         set_name   set_type  digital    rarity border_color  \
# 0      False  7ed  Seventh Edition       core    False      rare        white
# 1      False  m14       Magic 2014       core    False    common        black
# 2      False  c19   Commander 2019  commander    False      rare        black
# 3      False  9ed    Ninth Edition       core    False    common        white
# 4      False  ulg    Urza's Legacy  expansion    False  uncommon        black
#
#   power toughness card_faces loyalty
# 0   NaN       NaN        NaN     NaN
# 1   NaN       NaN        NaN     NaN
# 2   NaN       NaN        NaN     NaN
# 3     1         2        NaN     NaN
# 4     1         1        NaN     NaN

# %%
df.columns
# Out:
# Index(['object', 'name', 'scryfall_uri', 'layout', 'mana_cost', 'cmc',
#        'type_line', 'oracle_text', 'colors', 'color_identity', 'legalities',
#        'oversized', 'set', 'set_name', 'set_type', 'digital', 'rarity',
#        'border_color', 'power', 'toughness', 'card_faces', 'loyalty'],
#       dtype='object')

# %% [markdown]
# Also drop oversized cards

# %%
df = df.drop(df[df['oversized'] == True].index)

# %%
df = df.drop(columns=['oversized', 'digital'])

# %% [markdown]
# ___
# ### check for nulls

# %%
df.isnull().sum()
# Out:
# object                0
# name                  0
# scryfall_uri          0
# layout                0
# mana_cost           193
# cmc                   0
# type_line             0
# oracle_text         333
# colors              193
# color_identity        0
# legalities            0
# set                   0
# set_name              0
# set_type              0
# rarity                0
# border_color          0
# power              9702
# toughness          9702
# card_faces        20262
# loyalty           20400
# dtype: int64

# %%
df.shape
# Out:
# (20595, 20)

# %% [markdown]
# Art Series cards only existed in the modern horrizon set and are not actual cards, so we should drop them from our data set

# %%
df = df.drop(df[df['layout'] == 'art_series'].index)

# %%
# drop all the cards from the joke sets, because they are not legal in any format
df = df.drop(df[(df['set'] == 'unh') | (df['set'] == 'ugl') | (df['set'] == 'ust')].index)

# %%
df['border_color'].value_counts()
# Out:
# black         19299
# white           681
# gold             72
# silver           28
# borderless        1
# Name: border_color, dtype: int64

# %%
# drop any remaining gold or silver bordered cards because those are not legal either
df = df.drop(df.loc[(df['border_color'] == 'gold') | (df['border_color'] == 'silver')].index)

# %% [markdown]
# ### drop tokens and non-legal cards

# %%
df['layout'].value_counts()
# Out:
# normal                19189
# token                   345
# transform               104
# split                    86
# vanguard                 75
# emblem                   51
# double_faced_token       33
# adventure                30
# leveler                  25
# flip                     20
# saga                     14
# meld                      9
# Name: layout, dtype: int64

# %%
non_cards_index = df[(df['layout'] == 'double_faced_token') | (df['layout'] == 'token') | 
                             (df['layout'] == 'vanguard') | (df['layout'] == 'emblem')].index

# %%
df = df.drop(non_cards_index)
df = df.drop(df[df['set_type'] == 'token'].index)
df.shape
# Out:
# (19423, 20)

# %%
df['set_type'].value_counts()
# Out:
# expansion           11514
# masters              2333
# core                 1918
# commander            1536
# duel_deck             739
# draft_innovation      734
# starter               274
# planechase            126
# funny                 125
# archenemy              97
# memorabilia            10
# treasure_chest          8
# box                     5
# promo                   4
# Name: set_type, dtype: int64

# %%
df.loc[df['set_type'] == 'funny']['set'].value_counts()
# Out:
# cmb1     120
# htr17      3
# htr18      1
# hho        1
# Name: set, dtype: int64

# %%
# the sets cmb1, htr17, and hho are not legal in any format so let's drop them
joke_cards_index = df.loc[(df['set'] == 'hho') | (df['set'] == 'htr17') | (df['set'] == 'cmb1')].index
df = df.drop(joke_cards_index)

# %%
# cards with the memorabilia set_type are also not legal in any format, so let's drop those as well.
non_legal_index = df.loc[df['set_type'] == 'memorabilia'].index
df = df.drop(non_legal_index)

# %%
# conspiracy cards are also not legal in any format
conspiracy_index = df.loc[df['type_line'] == 'Conspiracy'].index
df = df.drop(conspiracy_index)

# %%
# now that we've cleaned up the df a little, we can drop some more extraneous columns
df = df.drop(columns=['set', 'set_name', 'set_type', 'border_color'])

# %%
df.isnull().sum()
# Out:
# object                0
# name                  0
# scryfall_uri          0
# layout                0
# mana_cost           104
# cmc                   0
# type_line             0
# oracle_text         237
# colors              104
# color_identity        0
# legalities            0
# rarity                0
# power              8990
# toughness          8990
# card_faces        19027
# loyalty           19077
# dtype: int64

# %%
df[df['colors'].isnull()]['layout'].value_counts()
# Out:
# transform    104
# Name: layout, dtype: int64

# %%
df[df['mana_cost'].isnull()]['layout'].value_counts()
# Out:
# transform    104
# Name: layout, dtype: int64

# %%
df[df['oracle_text'].isnull()]['layout'].value_counts()
# Out:
# transform    104
# split         83
# adventure     30
# flip          20
# Name: layout, dtype: int64

# %%
df = df.reset_index(drop=True)
df.head()
# Out:
#   object                 name  \
# 0   card           Static Orb
# 1   card  Sensory Deprivation
# 2   card       Road of Return
# 3   card           Storm Crow
# 4   card       Walking Sponge
#
#                                         scryfall_uri  layout mana_cost  cmc  \
# 0  https://scryfall.com/card/7ed/319/static-orb?u...  normal       {3}  3.0
# 1  https://scryfall.com/card/m14/71/sensory-depri...  normal       {U}  1.0
# 2  https://scryfall.com/card/c19/34/road-of-retur...  normal    {G}{G}  2.0
# 3  https://scryfall.com/card/9ed/100/storm-crow?u...  normal    {1}{U}  2.0
# 4  https://scryfall.com/card/ulg/47/walking-spong...  normal    {1}{U}  2.0
#
#             type_line                                        oracle_text  \
# 0            Artifact  As long as Static Orb is untapped, players can...
# 1  Enchantment — Aura   Enchant creature\nEnchanted creature gets -3/-0.
# 2             Sorcery  Choose one —\n• Return target permanent card f...
# 3     Creature — Bird  Flying (This creature can't be blocked except ...
# 4   Creature — Sponge  {T}: Target creature loses your choice of flyi...
#
#   colors color_identity                                         legalities  \
# 0     []             []  {'standard': 'not_legal', 'future': 'not_legal...
# 1    [U]            [U]  {'standard': 'not_legal', 'future': 'not_legal...
# 2    [G]            [G]  {'standard': 'not_legal', 'future': 'not_legal...
# 3    [U]            [U]  {'standard': 'not_legal', 'future': 'not_legal...
# 4    [U]            [U]  {'standard': 'not_legal', 'future': 'not_legal...
#
#      rarity power toughness card_faces loyalty
# 0      rare   NaN       NaN        NaN     NaN
# 1    common   NaN       NaN        NaN     NaN
# 2      rare   NaN       NaN        NaN     NaN
# 3    common     1         2        NaN     NaN
# 4  uncommon     1         1        NaN     NaN

# %% [markdown]
# ___
# From here I'd like to deal with the dual cards (transform, split, adventure, and flip cards).
#
# For flip and transform cards I want to keep the names the same because I want the recommender to recommend the whole card, not just one half of it.

# %% [markdown]
# First let's deal with the transform cards.
# Since transform cards can have different values on each side, I'm going to make another column that keeps track of the transformed side's values. For example, the entry for Delver of Secrets // Insectile Aberration will be one row however will have a power column that will be Delver of Secrets's power and another column that will be Insectile Aberration's power. Same thing for other values on the card

# %%
trans_df = df.loc[df['layout'] == 'transform']
trans_df.head()
# Out:
#     object                                               name  \
# 208   card         Ulvenwald Captive // Ulvenwald Abomination
# 405   card        Westvale Abbey // Ormendahl, Profane Prince
# 652   card           Extricator of Sin // Extricator of Flesh
# 841   card                      Treasure Map // Treasure Cove
# 989   card  Ulrich of the Krallenhorde // Ulrich, Uncontes...
#
#                                           scryfall_uri     layout mana_cost  \
# 208  https://scryfall.com/card/emn/175/ulvenwald-ca...  transform       NaN
# 405  https://scryfall.com/card/soi/281/westvale-abb...  transform       NaN
# 652  https://scryfall.com/card/emn/23/extricator-of...  transform       NaN
# 841  https://scryfall.com/card/xln/250/treasure-map...  transform       NaN
# 989  https://scryfall.com/card/emn/191/ulrich-of-th...  transform       NaN
#
#      cmc                                          type_line oracle_text  \
# 208  2.0  Creature — Werewolf Horror // Creature — Eldra...         NaN
# 405  0.0                 Land // Legendary Creature — Demon         NaN
# 652  3.0  Creature — Human Cleric // Creature — Eldrazi ...         NaN
# 841  2.0                                   Artifact // Land         NaN
# 989  5.0  Legendary Creature — Human Werewolf // Legenda...         NaN
#
#     colors color_identity                                         legalities  \
# 208    NaN            [G]  {'standard': 'not_legal', 'future': 'not_legal...
# 405    NaN            [B]  {'standard': 'not_legal', 'future': 'not_legal...
# 652    NaN            [W]  {'standard': 'not_legal', 'future': 'not_legal...
# 841    NaN             []  {'standard': 'not_legal', 'future': 'not_legal...
# 989    NaN         [G, R]  {'standard': 'not_legal', 'future': 'not_legal...
#
#        rarity power toughness  \
# 208    common   NaN       NaN
# 405      rare   NaN       NaN
# 652  uncommon   NaN       NaN
# 841      rare   NaN       NaN
# 989    mythic   NaN       NaN
#
#                                             card_faces loyalty
# 208  [{'object': 'card_face', 'name': 'Ulvenwald Ca...     NaN
# 405  [{'object': 'card_face', 'name': 'Westvale Abb...     NaN
# 652  [{'object': 'card_face', 'name': 'Extricator o...     NaN
# 841  [{'object': 'card_face', 'name': 'Treasure Map...     NaN
# 989  [{'object': 'card_face', 'name': 'Ulrich of th...     NaN

# %%
# set up empty lists to fill
# first set of lists are for the front half
mana_cost_list = []
oracle_text_list = []
colors_list = []
power_list = []
toughness_list = []
loyalty_list = []
card_type_list = []

# second set of lists are for the back half. We don't need mana cost for transformed sides because they are treated
# as the same as the front side
oracle_text_back_list = []
colors_back_list = []
power_back_list = []
toughness_back_list = []
loyalty_back_list = []
card_type_back_list = []

# iterate through our list of transform cards
for index in trans_df.index:
    
    # Front half of the cards
    mana_cost_list.append(trans_df.loc[index, 'card_faces'][0]['mana_cost'])
    oracle_text_list.append(trans_df.loc[index, 'card_faces'][0]['oracle_text'])
    colors_list.append(trans_df.loc[index, 'card_faces'][0]['colors'])
    # doing some try/excepts becuase not all cards have power, toughness, or loyalty
    try:
        power_list.append(trans_df.loc[index, 'card_faces'][0]['power'])
    except:
        power_list.append('NONE')
    try:
        toughness_list.append(trans_df.loc[index, 'card_faces'][0]['toughness'])
    except:
        toughness_list.append('NONE')
    try:
        loyalty_list.append(trans_df.loc[index, 'card_faces'][0]['loyalty'])
    except:
        loyalty_list.append('NONE')
    card_type_list.append(trans_df.loc[index, 'card_faces'][0]['type_line'].split(' — ')[0])
    
    # Back half of the cards
    oracle_text_back_list.append(trans_df.loc[index, 'card_faces'][1]['oracle_text'])
    colors_back_list.append(trans_df.loc[index, 'card_faces'][1]['colors'])
    try:
        power_back_list.append(trans_df.loc[index, 'card_faces'][1]['power'])
    except:
        power_back_list.append('NONE')
    try:
        toughness_back_list.append(trans_df.loc[index, 'card_faces'][1]['toughness'])
    except:
        toughness_back_list.append('NONE')
    try:
        loyalty_back_list.append(trans_df.loc[index, 'card_faces'][1]['loyalty'])
    except:
        loyalty_back_list.append('NONE')
    card_type_back_list.append(trans_df.loc[index, 'card_faces'][1]['type_line'].split(' — ')[0])
    
# fill in our values for the front half
df.loc[trans_df.index, 'mana_cost'] = mana_cost_list
df.loc[trans_df.index, 'oracle_text'] = oracle_text_list
df.loc[trans_df.index, 'colors'] = colors_list
df.loc[trans_df.index, 'power'] = power_list
df.loc[trans_df.index, 'toughness'] = toughness_list
df.loc[trans_df.index, 'loyalty'] = loyalty_list
df.loc[trans_df.index, 'card_type'] = card_type_list

# fill in our values for the back half
df.loc[trans_df.index, 'oracle_text_back'] = oracle_text_back_list
df.loc[trans_df.index, 'colors_back'] = colors_back_list
df.loc[trans_df.index, 'power_back'] = power_back_list
df.loc[trans_df.index, 'toughness_back'] = toughness_back_list
df.loc[trans_df.index, 'loyalty_back'] = loyalty_back_list
df.loc[trans_df.index, 'card_type_back'] = card_type_back_list

# %%
df.loc[trans_df.index].head()
# Out:
#     object                                               name  \
# 208   card         Ulvenwald Captive // Ulvenwald Abomination
# 405   card        Westvale Abbey // Ormendahl, Profane Prince
# 652   card           Extricator of Sin // Extricator of Flesh
# 841   card                      Treasure Map // Treasure Cove
# 989   card  Ulrich of the Krallenhorde // Ulrich, Uncontes...
#
#                                           scryfall_uri     layout  mana_cost  \
# 208  https://scryfall.com/card/emn/175/ulvenwald-ca...  transform     {1}{G}
# 405  https://scryfall.com/card/soi/281/westvale-abb...  transform
# 652  https://scryfall.com/card/emn/23/extricator-of...  transform     {2}{W}
# 841  https://scryfall.com/card/xln/250/treasure-map...  transform        {2}
# 989  https://scryfall.com/card/emn/191/ulrich-of-th...  transform  {3}{R}{G}
#
#      cmc                                          type_line  \
# 208  2.0  Creature — Werewolf Horror // Creature — Eldra...
# 405  0.0                 Land // Legendary Creature — Demon
# 652  3.0  Creature — Human Cleric // Creature — Eldrazi ...
# 841  2.0                                   Artifact // Land
# 989  5.0  Legendary Creature — Human Werewolf // Legenda...
#
#                                            oracle_text  colors color_identity  \
# 208  Defender\n{T}: Add {G}.\n{5}{G}{G}: Transform ...     [G]            [G]
# 405  {T}: Add {C}.\n{5}, {T}, Pay 1 life: Create a ...      []            [B]
# 652  When Extricator of Sin enters the battlefield,...     [W]            [W]
# 841  {1}, {T}: Scry 1. Put a landmark counter on Tr...      []             []
# 989  Whenever this creature enters the battlefield ...  [G, R]         [G, R]
#
#                                             legalities    rarity power  \
# 208  {'standard': 'not_legal', 'future': 'not_legal...    common     1
# 405  {'standard': 'not_legal', 'future': 'not_legal...      rare  NONE
# 652  {'standard': 'not_legal', 'future': 'not_legal...  uncommon     0
# 841  {'standard': 'not_legal', 'future': 'not_legal...      rare  NONE
# 989  {'standard': 'not_legal', 'future': 'not_legal...    mythic     4
#
#     toughness                                         card_faces loyalty  \
# 208         2  [{'object': 'card_face', 'name': 'Ulvenwald Ca...    NONE
# 405      NONE  [{'object': 'card_face', 'name': 'Westvale Abb...    NONE
# 652         3  [{'object': 'card_face', 'name': 'Extricator o...    NONE
# 841      NONE  [{'object': 'card_face', 'name': 'Treasure Map...    NONE
# 989         4  [{'object': 'card_face', 'name': 'Ulrich of th...    NONE
#
#               card_type                                   oracle_text_back  \
# 208            Creature                                   {T}: Add {C}{C}.
# 405                Land            Flying, lifelink, indestructible, haste
# 652            Creature  Eldrazi you control have vigilance.\n{2}, {T},...
# 841            Artifact  (Transforms from Treasure Map.)\n{T}: Add {C}....
# 989  Legendary Creature  Whenever this creature transforms into Ulrich,...
#
#     colors_back power_back toughness_back loyalty_back      card_type_back
# 208          []          4              6         NONE            Creature
# 405         [B]          9              7         NONE  Legendary Creature
# 652          []          3              5         NONE            Creature
# 841          []       NONE           NONE         NONE                Land
# 989      [G, R]          6              6         NONE  Legendary Creature

# %% [markdown]
# Next let's deal with flip cards

# %%
flip_df = df.loc[df['layout'] == 'flip'].copy()
flip_df.head()
# Out:
#      object                                            name  \
# 1480   card  Nezumi Graverobber // Nighteyes the Desecrator
# 2626   card     Faithful Squire // Kaiso, Memory of Loyalty
# 3181   card         Jushi Apprentice // Tomoya the Revealer
# 4560   card  Cunning Bandit // Azamuki, Treachery Incarnate
# 5223   card      Nezumi Shortfang // Stabwhisker the Odious
#
#                                            scryfall_uri layout  mana_cost  \
# 1480  https://scryfall.com/card/cm2/71/nezumi-graver...   flip     {1}{B}
# 2626  https://scryfall.com/card/bok/3/faithful-squir...   flip  {1}{W}{W}
# 3181  https://scryfall.com/card/chk/70/jushi-apprent...   flip     {1}{U}
# 4560  https://scryfall.com/card/bok/99/cunning-bandi...   flip  {1}{R}{R}
# 5223  https://scryfall.com/card/chk/131/nezumi-short...   flip     {1}{B}
#
#       cmc                                          type_line oracle_text  \
# 1480  2.0  Creature — Rat Rogue // Legendary Creature — R...         NaN
# 2626  3.0  Creature — Human Soldier // Legendary Creature...         NaN
# 3181  2.0  Creature — Human Wizard // Legendary Creature ...         NaN
# 4560  3.0  Creature — Human Warrior // Legendary Creature...         NaN
# 5223  2.0  Creature — Rat Rogue // Legendary Creature — R...         NaN
#
#      colors color_identity                                         legalities  \
# 1480    [B]            [B]  {'standard': 'not_legal', 'future': 'not_legal...
# 2626    [W]            [W]  {'standard': 'not_legal', 'future': 'not_legal...
# 3181    [U]            [U]  {'standard': 'not_legal', 'future': 'not_legal...
# 4560    [R]            [R]  {'standard': 'not_legal', 'future': 'not_legal...
# 5223    [B]            [B]  {'standard': 'not_legal', 'future': 'not_legal...
#
#         rarity power toughness  \
# 1480  uncommon     2         1
# 2626  uncommon     2         2
# 3181      rare     1         2
# 4560  uncommon     2         2
# 5223      rare     1         1
#
#                                              card_faces loyalty card_type  \
# 1480  [{'object': 'card_face', 'name': 'Nezumi Grave...     NaN       NaN
# 2626  [{'object': 'card_face', 'name': 'Faithful Squ...     NaN       NaN
# 3181  [{'object': 'card_face', 'name': 'Jushi Appren...     NaN       NaN
# 4560  [{'object': 'card_face', 'name': 'Cunning Band...     NaN       NaN
# 5223  [{'object': 'card_face', 'name': 'Nezumi Short...     NaN       NaN
#
#      oracle_text_back colors_back power_back toughness_back loyalty_back  \
# 1480              NaN         NaN        NaN            NaN          NaN
# 2626              NaN         NaN        NaN            NaN          NaN
# 3181              NaN         NaN        NaN            NaN          NaN
# 4560              NaN         NaN        NaN            NaN          NaN
# 5223              NaN         NaN        NaN            NaN          NaN
#
#      card_type_back
# 1480            NaN
# 2626            NaN
# 3181            NaN
# 4560            NaN
# 5223            NaN

# %%
# set up empty lists to fill
# first set of lists are for the front half
oracle_text_list = []
power_list = []
toughness_list = []
card_type_list = []

# second set of lists are for the back half. We don't need mana cost for transformed sides because they are treated
# as the same as the front side
oracle_text_back_list = []
power_back_list = []
toughness_back_list = []
card_type_back_list = []

# iterate through our list of transform cards
for index in flip_df.index:
    
    # Front half of the cards
    oracle_text_list.append(flip_df.loc[index, 'card_faces'][0]['oracle_text'])
    # doing some try/excepts becuase not all cards have power, toughness, or loyalty
    try:
        power_list.append(flip_df.loc[index, 'card_faces'][0]['power'])
    except:
        power_list.append('NONE')
    try:
        toughness_list.append(flip_df.loc[index, 'card_faces'][0]['toughness'])
    except:
        toughness_list.append('NONE')
    card_type_list.append(flip_df.loc[index, 'card_faces'][0]['type_line'].split(' — ')[0])
    
    # Back half of the cards
    oracle_text_back_list.append(flip_df.loc[index, 'card_faces'][1]['oracle_text'])
    try:
        power_back_list.append(flip_df.loc[index, 'card_faces'][1]['power'])
    except:
        power_back_list.append('NONE')
    try:
        toughness_back_list.append(flip_df.loc[index, 'card_faces'][1]['toughness'])
    except:
        toughness_back_list.append('NONE')
    card_type_back_list.append(flip_df.loc[index, 'card_faces'][1]['type_line'].split(' — ')[0])
    
# fill in our values for the front half
df.loc[flip_df.index, 'oracle_text'] = oracle_text_list
df.loc[flip_df.index, 'power'] = power_list
df.loc[flip_df.index, 'toughness'] = toughness_list
df.loc[flip_df.index, 'card_type'] = card_type_list

# fill in our values for the back half
df.loc[flip_df.index, 'oracle_text_back'] = oracle_text_back_list
df.loc[flip_df.index, 'power_back'] = power_back_list
df.loc[flip_df.index, 'toughness_back'] = toughness_back_list
df.loc[flip_df.index, 'card_type_back'] = card_type_back_list

# %%
df.loc[flip_df.index].head()
# Out:
#      object                                            name  \
# 1480   card  Nezumi Graverobber // Nighteyes the Desecrator
# 2626   card     Faithful Squire // Kaiso, Memory of Loyalty
# 3181   card         Jushi Apprentice // Tomoya the Revealer
# 4560   card  Cunning Bandit // Azamuki, Treachery Incarnate
# 5223   card      Nezumi Shortfang // Stabwhisker the Odious
#
#                                            scryfall_uri layout  mana_cost  \
# 1480  https://scryfall.com/card/cm2/71/nezumi-graver...   flip     {1}{B}
# 2626  https://scryfall.com/card/bok/3/faithful-squir...   flip  {1}{W}{W}
# 3181  https://scryfall.com/card/chk/70/jushi-apprent...   flip     {1}{U}
# 4560  https://scryfall.com/card/bok/99/cunning-bandi...   flip  {1}{R}{R}
# 5223  https://scryfall.com/card/chk/131/nezumi-short...   flip     {1}{B}
#
#       cmc                                          type_line  \
# 1480  2.0  Creature — Rat Rogue // Legendary Creature — R...
# 2626  3.0  Creature — Human Soldier // Legendary Creature...
# 3181  2.0  Creature — Human Wizard // Legendary Creature ...
# 4560  3.0  Creature — Human Warrior // Legendary Creature...
# 5223  2.0  Creature — Rat Rogue // Legendary Creature — R...
#
#                                             oracle_text colors color_identity  \
# 1480  {1}{B}: Exile target card from an opponent's g...    [B]            [B]
# 2626  Whenever you cast a Spirit or Arcane spell, yo...    [W]            [W]
# 3181  {2}{U}, {T}: Draw a card. If you have nine or ...    [U]            [U]
# 4560  Whenever you cast a Spirit or Arcane spell, yo...    [R]            [R]
# 5223  {1}{B}, {T}: Target opponent discards a card. ...    [B]            [B]
#
#                                              legalities    rarity power  \
# 1480  {'standard': 'not_legal', 'future': 'not_legal...  uncommon     2
# 2626  {'standard': 'not_legal', 'future': 'not_legal...  uncommon     2
# 3181  {'standard': 'not_legal', 'future': 'not_legal...      rare     1
# 4560  {'standard': 'not_legal', 'future': 'not_legal...  uncommon     2
# 5223  {'standard': 'not_legal', 'future': 'not_legal...      rare     1
#
#      toughness                                         card_faces loyalty  \
# 1480         1  [{'object': 'card_face', 'name': 'Nezumi Grave...     NaN
# 2626         2  [{'object': 'card_face', 'name': 'Faithful Squ...     NaN
# 3181         2  [{'object': 'card_face', 'name': 'Jushi Appren...     NaN
# 4560         2  [{'object': 'card_face', 'name': 'Cunning Band...     NaN
# 5223         1  [{'object': 'card_face', 'name': 'Nezumi Short...     NaN
#
#      card_type                                   oracle_text_back colors_back  \
# 1480  Creature  {4}{B}: Put target creature card from a gravey...         NaN
# 2626  Creature  Flying\nRemove a ki counter from Kaiso, Memory...         NaN
# 3181  Creature  {3}{U}{U}, {T}: Target player draws X cards, w...         NaN
# 4560  Creature  Remove a ki counter from Azamuki, Treachery In...         NaN
# 5223  Creature  At the beginning of each opponent's upkeep, th...         NaN
#
#      power_back toughness_back loyalty_back      card_type_back
# 1480          4              2          NaN  Legendary Creature
# 2626          3              4          NaN  Legendary Creature
# 3181          2              3          NaN  Legendary Creature
# 4560          5              2          NaN  Legendary Creature
# 5223          3              3          NaN  Legendary Creature

# %% [markdown]
# Next, let's deal with the adventure cards.
# Adventure cards are different from flip and transform cards in that you could play either half of the card and not the other. However, in terms of cleaning we'll treat them the same

# %%
adv_df = df.loc[df['layout'] == 'adventure'].copy()
adv_df.head()
# Out:
#      object                                   name  \
# 408    card  Faerie Guidemother // Gift of the Fae
# 680    card        Tuinvale Treefolk // Oaken Boon
# 1250   card           Murderous Rider // Swift End
# 1279   card     Foulmire Knight // Profane Insight
# 1340   card     Smitten Swordmaster // Curry Favor
#
#                                            scryfall_uri     layout  \
# 408   https://scryfall.com/card/eld/11/faerie-guidem...  adventure
# 680   https://scryfall.com/card/eld/180/tuinvale-tre...  adventure
# 1250  https://scryfall.com/card/eld/97/murderous-rid...  adventure
# 1279  https://scryfall.com/card/eld/286/foulmire-kni...  adventure
# 1340  https://scryfall.com/card/eld/290/smitten-swor...  adventure
#
#                    mana_cost  cmc  \
# 408            {W} // {1}{W}  1.0
# 680         {5}{G} // {3}{G}  6.0
# 1250  {1}{B}{B} // {1}{B}{B}  3.0
# 1279           {B} // {2}{B}  1.0
# 1340           {1}{B} // {B}  2.0
#
#                                              type_line oracle_text colors  \
# 408           Creature — Faerie // Sorcery — Adventure         NaN    [W]
# 680   Creature — Treefolk Druid // Sorcery — Adventure         NaN    [G]
# 1250   Creature — Zombie Knight // Instant — Adventure         NaN    [B]
# 1279   Creature — Zombie Knight // Instant — Adventure         NaN    [B]
# 1340    Creature — Human Knight // Sorcery — Adventure         NaN    [B]
#
#      color_identity                                         legalities  \
# 408             [W]  {'standard': 'legal', 'future': 'legal', 'hist...
# 680             [G]  {'standard': 'legal', 'future': 'legal', 'hist...
# 1250            [B]  {'standard': 'legal', 'future': 'legal', 'hist...
# 1279            [B]  {'standard': 'legal', 'future': 'legal', 'hist...
# 1340            [B]  {'standard': 'legal', 'future': 'legal', 'hist...
#
#         rarity power toughness  \
# 408     common     1         1
# 680     common     6         5
# 1250      rare     2         3
# 1279  uncommon     1         1
# 1340    common     2         1
#
#                                              card_faces loyalty card_type  \
# 408   [{'object': 'card_face', 'name': 'Faerie Guide...     NaN       NaN
# 680   [{'object': 'card_face', 'name': 'Tuinvale Tre...     NaN       NaN
# 1250  [{'object': 'card_face', 'name': 'Murderous Ri...     NaN       NaN
# 1279  [{'object': 'card_face', 'name': 'Foulmire Kni...     NaN       NaN
# 1340  [{'object': 'card_face', 'name': 'Smitten Swor...     NaN       NaN
#
#      oracle_text_back colors_back power_back toughness_back loyalty_back  \
# 408               NaN         NaN        NaN            NaN          NaN
# 680               NaN         NaN        NaN            NaN          NaN
# 1250              NaN         NaN        NaN            NaN          NaN
# 1279              NaN         NaN        NaN            NaN          NaN
# 1340              NaN         NaN        NaN            NaN          NaN
#
#      card_type_back
# 408             NaN
# 680             NaN
# 1250            NaN
# 1279            NaN
# 1340            NaN

# %%
# set up empty lists to fill
# first set of lists are for the creature half
mana_cost_list = []
oracle_text_list = []
power_list = []
toughness_list = []
card_type_list = []

# second set of lists are for the adventure half
oracle_text_back_list = []
card_type_back_list = []
mana_cost_back_list = []

# iterate through our list of adventure cards
for index in adv_df.index:
    
    # creature half of the cards
    mana_cost_list.append(adv_df.loc[index, 'card_faces'][0]['mana_cost'])
    oracle_text_list.append(adv_df.loc[index, 'card_faces'][0]['oracle_text'])
    power_list.append(adv_df.loc[index, 'card_faces'][0]['power'])
    toughness_list.append(adv_df.loc[index, 'card_faces'][0]['toughness'])
    card_type_list.append(adv_df.loc[index, 'card_faces'][0]['type_line'].split(' — ')[0])
    
    # adventure half of the cards
    mana_cost_back_list.append(adv_df.loc[index, 'card_faces'][1]['mana_cost'])
    oracle_text_back_list.append(adv_df.loc[index, 'card_faces'][1]['oracle_text'])
    card_type_back_list.append(adv_df.loc[index, 'card_faces'][1]['type_line'].split(' — ')[0])
    
# fill in our values for the creature half
df.loc[adv_df.index, 'mana_cost'] = mana_cost_list
df.loc[adv_df.index, 'oracle_text'] = oracle_text_list
df.loc[adv_df.index, 'power'] = power_list
df.loc[adv_df.index, 'toughness'] = toughness_list
df.loc[adv_df.index, 'card_type'] = card_type_list

# fill in our values for the adventure half
df.loc[adv_df.index, 'mana_cost_back'] = mana_cost_back_list
df.loc[adv_df.index, 'oracle_text_back'] = oracle_text_back_list
df.loc[adv_df.index, 'card_type_back'] = card_type_back_list

# %%
df.loc[adv_df.index].head()
# Out:
#      object                                   name  \
# 408    card  Faerie Guidemother // Gift of the Fae
# 680    card        Tuinvale Treefolk // Oaken Boon
# 1250   card           Murderous Rider // Swift End
# 1279   card     Foulmire Knight // Profane Insight
# 1340   card     Smitten Swordmaster // Curry Favor
#
#                                            scryfall_uri     layout  mana_cost  \
# 408   https://scryfall.com/card/eld/11/faerie-guidem...  adventure        {W}
# 680   https://scryfall.com/card/eld/180/tuinvale-tre...  adventure     {5}{G}
# 1250  https://scryfall.com/card/eld/97/murderous-rid...  adventure  {1}{B}{B}
# 1279  https://scryfall.com/card/eld/286/foulmire-kni...  adventure        {B}
# 1340  https://scryfall.com/card/eld/290/smitten-swor...  adventure     {1}{B}
#
#       cmc                                         type_line  \
# 408   1.0          Creature — Faerie // Sorcery — Adventure
# 680   6.0  Creature — Treefolk Druid // Sorcery — Adventure
# 1250  3.0   Creature — Zombie Knight // Instant — Adventure
# 1279  1.0   Creature — Zombie Knight // Instant — Adventure
# 1340  2.0    Creature — Human Knight // Sorcery — Adventure
#
#                                             oracle_text colors color_identity  \
# 408                                              Flying    [W]            [W]
# 680                                                        [G]            [G]
# 1250  Lifelink\nWhen Murderous Rider dies, put it on...    [B]            [B]
# 1279                                         Deathtouch    [B]            [B]
# 1340                                           Lifelink    [B]            [B]
#
#                                              legalities    rarity power  \
# 408   {'standard': 'legal', 'future': 'legal', 'hist...    common     1
# 680   {'standard': 'legal', 'future': 'legal', 'hist...    common     6
# 1250  {'standard': 'legal', 'future': 'legal', 'hist...      rare     2
# 1279  {'standard': 'legal', 'future': 'legal', 'hist...  uncommon     1
# 1340  {'standard': 'legal', 'future': 'legal', 'hist...    common     2
#
#      toughness                                         card_faces loyalty  \
# 408          1  [{'object': 'card_face', 'name': 'Faerie Guide...     NaN
# 680          5  [{'object': 'card_face', 'name': 'Tuinvale Tre...     NaN
# 1250         3  [{'object': 'card_face', 'name': 'Murderous Ri...     NaN
# 1279         1  [{'object': 'card_face', 'name': 'Foulmire Kni...     NaN
# 1340         1  [{'object': 'card_face', 'name': 'Smitten Swor...     NaN
#
#      card_type                                   oracle_text_back colors_back  \
# 408   Creature  Target creature gets +2/+1 and gains flying un...         NaN
# 680   Creature  Put two +1/+1 counters on target creature. (Th...         NaN
# 1250  Creature  Destroy target creature or planeswalker. You l...         NaN
# 1279  Creature  You draw a card and you lose 1 life. (Then exi...         NaN
# 1340  Creature  You gain X life and each opponent loses X life...         NaN
#
#      power_back toughness_back loyalty_back card_type_back mana_cost_back
# 408         NaN            NaN          NaN        Sorcery         {1}{W}
# 680         NaN            NaN          NaN        Sorcery         {3}{G}
# 1250        NaN            NaN          NaN        Instant      {1}{B}{B}
# 1279        NaN            NaN          NaN        Instant         {2}{B}
# 1340        NaN            NaN          NaN        Sorcery            {B}

# %% [markdown]
# Finally, we'll deal with the split cards

# %%
split_df = df.loc[df['layout'] == 'split'].copy()
split_df.head()
# Out:
#     object                  name  \
# 313   card       Heaven // Earth
# 342   card  Breaking // Entering
# 568   card        Flesh // Blood
# 630   card    Assure // Assemble
# 828   card   Struggle // Survive
#
#                                           scryfall_uri layout  \
# 313  https://scryfall.com/card/akh/224/heaven-earth...  split
# 342  https://scryfall.com/card/dgm/124/breaking-ent...  split
# 568  https://scryfall.com/card/dgm/128/flesh-blood?...  split
# 630  https://scryfall.com/card/grn/221/assure-assem...  split
# 828  https://scryfall.com/card/hou/151/struggle-sur...  split
#
#                    mana_cost  cmc           type_line oracle_text     colors  \
# 313      {X}{G} // {X}{R}{R}  3.0  Instant // Sorcery         NaN     [G, R]
# 342      {U}{B} // {4}{B}{R}  8.0  Sorcery // Sorcery         NaN  [B, R, U]
# 568      {3}{B}{G} // {R}{G}  7.0  Sorcery // Sorcery         NaN  [B, G, R]
# 630  {G/W}{G/W} // {4}{G}{W}  8.0  Instant // Instant         NaN     [G, W]
# 828         {2}{R} // {1}{G}  5.0  Instant // Sorcery         NaN     [G, R]
#
#     color_identity                                         legalities  \
# 313         [G, R]  {'standard': 'not_legal', 'future': 'not_legal...
# 342      [B, R, U]  {'standard': 'not_legal', 'future': 'not_legal...
# 568      [B, G, R]  {'standard': 'not_legal', 'future': 'not_legal...
# 630         [G, W]  {'standard': 'legal', 'future': 'legal', 'hist...
# 828         [G, R]  {'standard': 'not_legal', 'future': 'not_legal...
#
#        rarity power toughness  \
# 313      rare   NaN       NaN
# 342      rare   NaN       NaN
# 568      rare   NaN       NaN
# 630      rare   NaN       NaN
# 828  uncommon   NaN       NaN
#
#                                             card_faces loyalty card_type  \
# 313  [{'object': 'card_face', 'name': 'Heaven', 'ma...     NaN       NaN
# 342  [{'object': 'card_face', 'name': 'Breaking', '...     NaN       NaN
# 568  [{'object': 'card_face', 'name': 'Flesh', 'man...     NaN       NaN
# 630  [{'object': 'card_face', 'name': 'Assure', 'ma...     NaN       NaN
# 828  [{'object': 'card_face', 'name': 'Struggle', '...     NaN       NaN
#
#     oracle_text_back colors_back power_back toughness_back loyalty_back  \
# 313              NaN         NaN        NaN            NaN          NaN
# 342              NaN         NaN        NaN            NaN          NaN
# 568              NaN         NaN        NaN            NaN          NaN
# 630              NaN         NaN        NaN            NaN          NaN
# 828              NaN         NaN        NaN            NaN          NaN
#
#     card_type_back mana_cost_back
# 313            NaN            NaN
# 342            NaN            NaN
# 568            NaN            NaN
# 630            NaN            NaN
# 828            NaN            NaN

# %%
# set up empty lists to fill
# first set of lists are for the front half
mana_cost_list = []
oracle_text_list = []
card_type_list = []

# second set of lists are for the back half.
mana_cost_back_list = []
oracle_text_back_list = []
card_type_back_list = []

# iterate through our list of transform cards
for index in split_df.index:
    
    # Front half of the cards
    mana_cost_list.append(split_df.loc[index, 'card_faces'][0]['mana_cost'])
    oracle_text_list.append(split_df.loc[index, 'card_faces'][0]['oracle_text'])
    card_type_list.append(split_df.loc[index, 'card_faces'][0]['type_line'].split(' — ')[0])
    
    # Back half of the cards
    mana_cost_back_list.append(split_df.loc[index, 'card_faces'][1]['mana_cost'])
    oracle_text_back_list.append(split_df.loc[index, 'card_faces'][1]['oracle_text'])
    card_type_back_list.append(split_df.loc[index, 'card_faces'][1]['type_line'].split(' — ')[0])
    
# fill in our values for the front half
df.loc[split_df.index, 'mana_cost'] = mana_cost_list
df.loc[split_df.index, 'oracle_text'] = oracle_text_list
df.loc[split_df.index, 'card_type'] = card_type_list

# fill in our values for the back half
df.loc[split_df.index, 'mana_cost_back'] = mana_cost_back_list
df.loc[split_df.index, 'oracle_text_back'] = oracle_text_back_list
df.loc[split_df.index, 'card_type_back'] = card_type_back_list

# %%
df.loc[split_df.index].head()
# Out:
#     object                  name  \
# 313   card       Heaven // Earth
# 342   card  Breaking // Entering
# 568   card        Flesh // Blood
# 630   card    Assure // Assemble
# 828   card   Struggle // Survive
#
#                                           scryfall_uri layout   mana_cost  \
# 313  https://scryfall.com/card/akh/224/heaven-earth...  split      {X}{G}
# 342  https://scryfall.com/card/dgm/124/breaking-ent...  split      {U}{B}
# 568  https://scryfall.com/card/dgm/128/flesh-blood?...  split   {3}{B}{G}
# 630  https://scryfall.com/card/grn/221/assure-assem...  split  {G/W}{G/W}
# 828  https://scryfall.com/card/hou/151/struggle-sur...  split      {2}{R}
#
#      cmc           type_line  \
# 313  3.0  Instant // Sorcery
# 342  8.0  Sorcery // Sorcery
# 568  7.0  Sorcery // Sorcery
# 630  8.0  Instant // Instant
# 828  5.0  Instant // Sorcery
#
#                                            oracle_text     colors  \
# 313  Heaven deals X damage to each creature with fl...     [G, R]
# 342  Target player puts the top eight cards of thei...  [B, R, U]
# 568  Exile target creature card from a graveyard. P...  [B, G, R]
# 630  Put a +1/+1 counter on target creature. That c...     [G, W]
# 828  Struggle deals damage to target creature equal...     [G, R]
#
#     color_identity                                         legalities  \
# 313         [G, R]  {'standard': 'not_legal', 'future': 'not_legal...
# 342      [B, R, U]  {'standard': 'not_legal', 'future': 'not_legal...
# 568      [B, G, R]  {'standard': 'not_legal', 'future': 'not_legal...
# 630         [G, W]  {'standard': 'legal', 'future': 'legal', 'hist...
# 828         [G, R]  {'standard': 'not_legal', 'future': 'not_legal...
#
#        rarity power toughness  \
# 313      rare   NaN       NaN
# 342      rare   NaN       NaN
# 568      rare   NaN       NaN
# 630      rare   NaN       NaN
# 828  uncommon   NaN       NaN
#
#                                             card_faces loyalty card_type  \
# 313  [{'object': 'card_face', 'name': 'Heaven', 'ma...     NaN   Instant
# 342  [{'object': 'card_face', 'name': 'Breaking', '...     NaN   Sorcery
# 568  [{'object': 'card_face', 'name': 'Flesh', 'man...     NaN   Sorcery
# 630  [{'object': 'card_face', 'name': 'Assure', 'ma...     NaN   Instant
# 828  [{'object': 'card_face', 'name': 'Struggle', '...     NaN   Instant
#
#                                       oracle_text_back colors_back power_back  \
# 313  Aftermath (Cast this spell only from your grav...         NaN        NaN
# 342  Put a creature card from a graveyard onto the ...         NaN        NaN
# 568  Target creature you control deals damage equal...         NaN        NaN
# 630  Create three 2/2 green and white Elf Knight cr...         NaN        NaN
# 828  Aftermath (Cast this spell only from your grav...         NaN        NaN
#
#     toughness_back loyalty_back card_type_back mana_cost_back
# 313            NaN          NaN        Sorcery      {X}{R}{R}
# 342            NaN          NaN        Sorcery      {4}{B}{R}
# 568            NaN          NaN        Sorcery         {R}{G}
# 630            NaN          NaN        Instant      {4}{G}{W}
# 828            NaN          NaN        Sorcery         {1}{G}

# %%
df.isnull().sum()
# Out:
# object                  0
# name                    0
# scryfall_uri            0
# layout                  0
# mana_cost               0
# cmc                     0
# type_line               0
# oracle_text             0
# colors                  0
# color_identity          0
# legalities              0
# rarity                  0
# power                8886
# toughness            8886
# card_faces          19027
# loyalty             18973
# card_type           19027
# oracle_text_back    19027
# colors_back         19160
# power_back          19140
# toughness_back      19140
# loyalty_back        19160
# card_type_back      19027
# mana_cost_back      19151
# dtype: int64

# %% [markdown]
# ___
# Let's get the card types from the type line

# %%
missing_card_type_index = df.loc[df['card_type'].isnull()].index

card_type_list = []

for index in missing_card_type_index:
    card_type_list.append(df.loc[index, 'type_line'].split(' — ')[0])
    
df.loc[missing_card_type_index, 'card_type'] = card_type_list

# %%
df['card_type'].value_counts()
# Out:
# Creature                          8763
# Instant                           2368
# Enchantment                       2179
# Sorcery                           2119
# Artifact                          1240
# Legendary Creature                 834
# Artifact Creature                  587
# Land                               585
# Legendary Planeswalker             189
# Enchantment Creature                69
# Legendary Artifact                  63
# Legendary Land                      41
# Snow Creature                       37
# Legendary Enchantment               30
# World Enchantment                   26
# Tribal Instant                      20
# Legendary Enchantment Creature      16
# Tribal Sorcery                      16
# Tribal Enchantment                  13
# Legendary Artifact Creature         13
# Snow Land                            8
# Snow Enchantment                     6
# Artifact Land                        6
# Legendary Sorcery                    6
# Basic Land                           6
# Legendary Enchantment Artifact       5
# Basic Snow Land                      5
# Tribal Artifact                      5
# Snow Artifact Creature               4
# Snow Artifact                        2
# Legendary Snow Land                  1
# Land Creature                        1
# Legendary Snow Enchantment           1
# Name: card_type, dtype: int64

# %%
df.isnull().sum()
# Out:
# object                  0
# name                    0
# scryfall_uri            0
# layout                  0
# mana_cost               0
# cmc                     0
# type_line               0
# oracle_text             0
# colors                  0
# color_identity          0
# legalities              0
# rarity                  0
# power                8886
# toughness            8886
# card_faces          19027
# loyalty             18973
# card_type               0
# oracle_text_back    19027
# colors_back         19160
# power_back          19140
# toughness_back      19140
# loyalty_back        19160
# card_type_back      19027
# mana_cost_back      19151
# dtype: int64

# %%
df.loc[df['power'].isnull()]['card_type'].value_counts()
# Out:
# Instant                           2368
# Enchantment                       2177
# Sorcery                           2118
# Artifact                          1208
# Land                               584
# Legendary Planeswalker             187
# Legendary Artifact                  57
# Legendary Land                      41
# World Enchantment                   26
# Tribal Instant                      20
# Legendary Enchantment               20
# Tribal Sorcery                      16
# Tribal Enchantment                  13
# Snow Land                            8
# Snow Enchantment                     6
# Artifact Land                        6
# Legendary Sorcery                    6
# Basic Land                           6
# Basic Snow Land                      5
# Legendary Enchantment Artifact       5
# Tribal Artifact                      5
# Snow Artifact                        2
# Legendary Snow Enchantment           1
# Legendary Snow Land                  1
# Name: card_type, dtype: int64

# %%
# The rest of the Nulls in the power and toughness columns are non-creatures so they don't have a power or
# toughness. We will impute those nulls as 'NONE'
df['power'] = df['power'].fillna('NONE')
df['toughness'] = df['toughness'].fillna('NONE')
df.isnull().sum()
# Out:
# object                  0
# name                    0
# scryfall_uri            0
# layout                  0
# mana_cost               0
# cmc                     0
# type_line               0
# oracle_text             0
# colors                  0
# color_identity          0
# legalities              0
# rarity                  0
# power                   0
# toughness               0
# card_faces          19027
# loyalty             18973
# card_type               0
# oracle_text_back    19027
# colors_back         19160
# power_back          19140
# toughness_back      19140
# loyalty_back        19160
# card_type_back      19027
# mana_cost_back      19151
# dtype: int64

# %%
df.loc[df['card_faces'].isnull()]['layout'].value_counts()
# Out:
# normal     18979
# leveler       25
# saga          14
# meld           9
# Name: layout, dtype: int64

# %%
# the rest of the Nulls for card_faces are for non-dual-cards, so let's impute those Nulls as 'NONE'
df['card_faces'] = df['card_faces'].fillna('NONE')

# %%
df.loc[df['loyalty'].isnull()]['card_type'].value_counts()
# Out:
# Creature                          8696
# Instant                           2368
# Enchantment                       2177
# Sorcery                           2118
# Artifact                          1232
# Legendary Creature                 826
# Artifact Creature                  584
# Land                               584
# Enchantment Creature                69
# Legendary Artifact                  61
# Legendary Land                      41
# Snow Creature                       37
# World Enchantment                   26
# Tribal Instant                      20
# Legendary Enchantment               20
# Legendary Enchantment Creature      16
# Tribal Sorcery                      16
# Tribal Enchantment                  13
# Legendary Artifact Creature         13
# Snow Land                            8
# Snow Enchantment                     6
# Artifact Land                        6
# Legendary Sorcery                    6
# Basic Land                           6
# Legendary Enchantment Artifact       5
# Basic Snow Land                      5
# Tribal Artifact                      5
# Snow Artifact Creature               4
# Snow Artifact                        2
# Legendary Snow Land                  1
# Land Creature                        1
# Legendary Snow Enchantment           1
# Name: card_type, dtype: int64

# %%
# the Nulls for loyalty are for non-planeswalker cards, so fill those Nulls as 'NONE'
df['loyalty'] = df['loyalty'].fillna('NONE')

# %%
# The rest of the Nulls are for back half of cards that are non-dual cards, so let's impute those as 'NONE'
df = df.fillna('NONE')
df.isnull().sum()
# Out:
# object              0
# name                0
# scryfall_uri        0
# layout              0
# mana_cost           0
# cmc                 0
# type_line           0
# oracle_text         0
# colors              0
# color_identity      0
# legalities          0
# rarity              0
# power               0
# toughness           0
# card_faces          0
# loyalty             0
# card_type           0
# oracle_text_back    0
# colors_back         0
# power_back          0
# toughness_back      0
# loyalty_back        0
# card_type_back      0
# mana_cost_back      0
# dtype: int64

# %%
df.loc[(df['mana_cost'] == "")]['card_type'].value_counts()
# Out:
# Land                   585
# Legendary Land          41
# Snow Land                8
# Artifact Land            6
# Sorcery                  6
# Basic Land               6
# Basic Snow Land          5
# Legendary Creature       2
# Artifact                 2
# Instant                  1
# Land Creature            1
# Creature                 1
# Legendary Snow Land      1
# Name: card_type, dtype: int64

# %%
# these mana costs should be None to avoid Null values later on
# according to the rules of magic no mana cost is different than a mana cost of {0}
no_mana_cost = df.loc[(df['mana_cost'] == "")].index
df.loc[no_mana_cost, 'mana_cost'] = 'NONE'

# %%
df.loc[no_mana_cost].head()
# Out:
#     object                       name  \
# 50    card  Shizo, Death's Storehouse
# 63    card               Timber Gorge
# 70    card                 Game Trail
# 77    card         Selesnya Sanctuary
# 126   card             Urborg Volcano
#
#                                           scryfall_uri  layout mana_cost  cmc  \
# 50   https://scryfall.com/card/chk/283/shizo-deaths...  normal      NONE  0.0
# 63   https://scryfall.com/card/m19/258/timber-gorge...  normal      NONE  0.0
# 70   https://scryfall.com/card/soi/276/game-trail?u...  normal      NONE  0.0
# 77   https://scryfall.com/card/c19/272/selesnya-san...  normal      NONE  0.0
# 126  https://scryfall.com/card/c17/288/urborg-volca...  normal      NONE  0.0
#
#           type_line                                        oracle_text colors  \
# 50   Legendary Land  {T}: Add {B}.\n{B}, {T}: Target legendary crea...     []
# 63             Land  Timber Gorge enters the battlefield tapped.\n{...     []
# 70             Land  As Game Trail enters the battlefield, you may ...     []
# 77             Land  Selesnya Sanctuary enters the battlefield tapp...     []
# 126            Land  Urborg Volcano enters the battlefield tapped.\...     []
#
#     color_identity                                         legalities  \
# 50             [B]  {'standard': 'not_legal', 'future': 'not_legal...
# 63          [G, R]  {'standard': 'not_legal', 'future': 'not_legal...
# 70          [G, R]  {'standard': 'not_legal', 'future': 'not_legal...
# 77          [G, W]  {'standard': 'not_legal', 'future': 'not_legal...
# 126         [B, R]  {'standard': 'not_legal', 'future': 'not_legal...
#
#        rarity power toughness card_faces loyalty       card_type  \
# 50       rare  NONE      NONE       NONE    NONE  Legendary Land
# 63     common  NONE      NONE       NONE    NONE            Land
# 70       rare  NONE      NONE       NONE    NONE            Land
# 77     common  NONE      NONE       NONE    NONE            Land
# 126  uncommon  NONE      NONE       NONE    NONE            Land
#
#     oracle_text_back colors_back power_back toughness_back loyalty_back  \
# 50              NONE        NONE       NONE           NONE         NONE
# 63              NONE        NONE       NONE           NONE         NONE
# 70              NONE        NONE       NONE           NONE         NONE
# 77              NONE        NONE       NONE           NONE         NONE
# 126             NONE        NONE       NONE           NONE         NONE
#
#     card_type_back mana_cost_back
# 50            NONE           NONE
# 63            NONE           NONE
# 70            NONE           NONE
# 77            NONE           NONE
# 126           NONE           NONE

# %%
# Any leftover blank oracle text entries are for vanilla creatures (meaning they have no abilities)
vanilla_creatures = df.loc[(df['oracle_text'] == "") | (df['oracle_text_back'] == "")].index

df.loc[vanilla_creatures, ['oracle_text', 'oracle_text_back']] = 'NONE'

df.loc[vanilla_creatures].head()
# Out:
#     object                  name  \
# 29    card  Leopard-Spotted Jiao
# 43    card       Dakmor Scorpion
# 55    card           Scaled Wurm
# 111   card     Oreskos Swiftclaw
# 119   card  Minotaur Abomination
#
#                                           scryfall_uri  layout  mana_cost  \
# 29   https://scryfall.com/card/gs1/23/leopard-spott...  normal     {1}{R}
# 43   https://scryfall.com/card/s99/73/dakmor-scorpi...  normal     {1}{B}
# 55   https://scryfall.com/card/cns/178/scaled-wurm?...  normal     {7}{G}
# 111  https://scryfall.com/card/m19/31/oreskos-swift...  normal     {1}{W}
# 119  https://scryfall.com/card/m14/107/minotaur-abo...  normal  {4}{B}{B}
#
#      cmc                   type_line oracle_text colors color_identity  \
# 29   2.0            Creature — Beast        NONE    [R]            [R]
# 43   2.0         Creature — Scorpion        NONE    [B]            [B]
# 55   8.0             Creature — Wurm        NONE    [G]            [G]
# 111  2.0      Creature — Cat Warrior        NONE    [W]            [W]
# 119  6.0  Creature — Zombie Minotaur        NONE    [B]            [B]
#
#                                             legalities  rarity power  \
# 29   {'standard': 'not_legal', 'future': 'not_legal...  common     3
# 43   {'standard': 'not_legal', 'future': 'not_legal...  common     2
# 55   {'standard': 'not_legal', 'future': 'not_legal...  common     7
# 111  {'standard': 'not_legal', 'future': 'not_legal...  common     3
# 119  {'standard': 'not_legal', 'future': 'not_legal...  common     4
#
#     toughness card_faces loyalty card_type oracle_text_back colors_back  \
# 29          1       NONE    NONE  Creature             NONE        NONE
# 43          1       NONE    NONE  Creature             NONE        NONE
# 55          6       NONE    NONE  Creature             NONE        NONE
# 111         1       NONE    NONE  Creature             NONE        NONE
# 119         6       NONE    NONE  Creature             NONE        NONE
#
#     power_back toughness_back loyalty_back card_type_back mana_cost_back
# 29        NONE           NONE         NONE           NONE           NONE
# 43        NONE           NONE         NONE           NONE           NONE
# 55        NONE           NONE         NONE           NONE           NONE
# 111       NONE           NONE         NONE           NONE           NONE
# 119       NONE           NONE         NONE           NONE           NONE

# %% [markdown]
# Now I'd like to break out the super-type of each card because by the rules of the game they are not considered to be card types. super-types include Basic, Legendary, Snow, and World

# %%
super_types = ['Legendary', 'Snow', 'World', 'Basic']

for card in df.index:
    
    card_super_type_list = []
    card_super_type_list_back = []

    for word in df.loc[card, 'card_type'].split():

        if word in super_types:
            card_super_type_list.append(word)
    
    for word in df.loc[card, 'card_type_back'].split():

        if word in super_types:
            card_super_type_list_back.append(word)
            
    
    if card_super_type_list == []:
        card_super_type_list = ['NONE']
        
    if card_super_type_list_back == []:
        card_super_type_list_back = ['NONE']
        
    df.loc[card, 'super_type'] = " ".join(card_super_type_list)
    df.loc[card, 'super_type_back'] = " ".join(card_super_type_list_back)
           
df.head()
# Out:
#   object                 name  \
# 0   card           Static Orb
# 1   card  Sensory Deprivation
# 2   card       Road of Return
# 3   card           Storm Crow
# 4   card       Walking Sponge
#
#                                         scryfall_uri  layout mana_cost  cmc  \
# 0  https://scryfall.com/card/7ed/319/static-orb?u...  normal       {3}  3.0
# 1  https://scryfall.com/card/m14/71/sensory-depri...  normal       {U}  1.0
# 2  https://scryfall.com/card/c19/34/road-of-retur...  normal    {G}{G}  2.0
# 3  https://scryfall.com/card/9ed/100/storm-crow?u...  normal    {1}{U}  2.0
# 4  https://scryfall.com/card/ulg/47/walking-spong...  normal    {1}{U}  2.0
#
#             type_line                                        oracle_text  \
# 0            Artifact  As long as Static Orb is untapped, players can...
# 1  Enchantment — Aura   Enchant creature\nEnchanted creature gets -3/-0.
# 2             Sorcery  Choose one —\n• Return target permanent card f...
# 3     Creature — Bird  Flying (This creature can't be blocked except ...
# 4   Creature — Sponge  {T}: Target creature loses your choice of flyi...
#
#   colors color_identity                                         legalities  \
# 0     []             []  {'standard': 'not_legal', 'future': 'not_legal...
# 1    [U]            [U]  {'standard': 'not_legal', 'future': 'not_legal...
# 2    [G]            [G]  {'standard': 'not_legal', 'future': 'not_legal...
# 3    [U]            [U]  {'standard': 'not_legal', 'future': 'not_legal...
# 4    [U]            [U]  {'standard': 'not_legal', 'future': 'not_legal...
#
#      rarity power toughness card_faces loyalty    card_type oracle_text_back  \
# 0      rare  NONE      NONE       NONE    NONE     Artifact             NONE
# 1    common  NONE      NONE       NONE    NONE  Enchantment             NONE
# 2      rare  NONE      NONE       NONE    NONE      Sorcery             NONE
# 3    common     1         2       NONE    NONE     Creature             NONE
# 4  uncommon     1         1       NONE    NONE     Creature             NONE
#
#   colors_back power_back toughness_back loyalty_back card_type_back  \
# 0        NONE       NONE           NONE         NONE           NONE
# 1        NONE       NONE           NONE         NONE           NONE
# 2        NONE       NONE           NONE         NONE           NONE
# 3        NONE       NONE           NONE         NONE           NONE
# 4        NONE       NONE           NONE         NONE           NONE
#
#   mana_cost_back super_type super_type_back
# 0           NONE       NONE            NONE
# 1           NONE       NONE            NONE
# 2           NONE       NONE            NONE
# 3           NONE       NONE            NONE
# 4           NONE       NONE            NONE

# %%
# now I'd like to remove the super_type from the card_type for each card
for index in df.loc[df['super_type'] != 'NONE'].index:
    df.loc[index, 'card_type'] = df.loc[index, 'card_type'].replace(df.loc[index, 'super_type'], '').strip()
    
# back half
for index in df.loc[df['super_type_back'] != 'NONE'].index:
    df.loc[index, 'card_type_back'] = df.loc[index, 'card_type_back'].replace(df.loc[index, 'super_type_back'], '').strip()

# %%
df['card_type'].value_counts()
# Out:
# Creature                9634
# Instant                 2368
# Enchantment             2242
# Sorcery                 2125
# Artifact                1305
# Land                     646
# Artifact Creature        604
# Planeswalker             189
# Enchantment Creature      85
# Tribal Instant            20
# Tribal Sorcery            16
# Tribal Enchantment        13
# Artifact Land              6
# Tribal Artifact            5
# Enchantment Artifact       5
# Land Creature              1
# Name: card_type, dtype: int64

# %%
df['card_type_back'].value_counts()
# Out:
# NONE                 19027
# Creature                88
# Sorcery                 69
# Instant                 44
# Land                    17
# Planeswalker             8
# Enchantment              7
# Artifact                 3
# Artifact Creature        1
# Name: card_type_back, dtype: int64

# %%
# this is to clean up the leaglities column a little
for index in df.index:
    legal_formats = []
    for form in df.loc[index, 'legalities']:
        if df.loc[index, 'legalities'][form] == 'legal' or df.loc[index, 'legalities'][form] == 'restricted':
            legal_formats.append(form)
    df.loc[index, 'legalities'] = " ".join(legal_formats)

# %%
df.loc[df['legalities'] == ''].shape
# Out:
# (20, 26)

# %%
# there are some other older cards that are not legal in any format, i.e. cards that refer to ante, so those 
# legalities need to be set to NONE to avoid Null values later.
non_legal_cards = df.loc[df['legalities'] == ""].index
df.loc[non_legal_cards, 'legalities'] = 'NONE'

# %%
df.head()
# Out:
#   object                 name  \
# 0   card           Static Orb
# 1   card  Sensory Deprivation
# 2   card       Road of Return
# 3   card           Storm Crow
# 4   card       Walking Sponge
#
#                                         scryfall_uri  layout mana_cost  cmc  \
# 0  https://scryfall.com/card/7ed/319/static-orb?u...  normal       {3}  3.0
# 1  https://scryfall.com/card/m14/71/sensory-depri...  normal       {U}  1.0
# 2  https://scryfall.com/card/c19/34/road-of-retur...  normal    {G}{G}  2.0
# 3  https://scryfall.com/card/9ed/100/storm-crow?u...  normal    {1}{U}  2.0
# 4  https://scryfall.com/card/ulg/47/walking-spong...  normal    {1}{U}  2.0
#
#             type_line                                        oracle_text  \
# 0            Artifact  As long as Static Orb is untapped, players can...
# 1  Enchantment — Aura   Enchant creature\nEnchanted creature gets -3/-0.
# 2             Sorcery  Choose one —\n• Return target permanent card f...
# 3     Creature — Bird  Flying (This creature can't be blocked except ...
# 4   Creature — Sponge  {T}: Target creature loses your choice of flyi...
#
#   colors color_identity                                         legalities  \
# 0     []             []                      legacy vintage commander duel
# 1    [U]            [U]  pioneer modern legacy pauper vintage penny com...
# 2    [G]            [G]                      legacy vintage commander duel
# 3    [U]            [U]  modern legacy pauper vintage penny commander duel
# 4    [U]            [U]                      legacy vintage commander duel
#
#      rarity power toughness card_faces loyalty    card_type oracle_text_back  \
# 0      rare  NONE      NONE       NONE    NONE     Artifact             NONE
# 1    common  NONE      NONE       NONE    NONE  Enchantment             NONE
# 2      rare  NONE      NONE       NONE    NONE      Sorcery             NONE
# 3    common     1         2       NONE    NONE     Creature             NONE
# 4  uncommon     1         1       NONE    NONE     Creature             NONE
#
#   colors_back power_back toughness_back loyalty_back card_type_back  \
# 0        NONE       NONE           NONE         NONE           NONE
# 1        NONE       NONE           NONE         NONE           NONE
# 2        NONE       NONE           NONE         NONE           NONE
# 3        NONE       NONE           NONE         NONE           NONE
# 4        NONE       NONE           NONE         NONE           NONE
#
#   mana_cost_back super_type super_type_back
# 0           NONE       NONE            NONE
# 1           NONE       NONE            NONE
# 2           NONE       NONE            NONE
# 3           NONE       NONE            NONE
# 4           NONE       NONE            NONE

# %% [markdown]
# Now is a good time to also get the sub_type of a card.
# Sub_types include: Aura, Vehicle, Arcane, Equipment, etc.
# For creatures sub_types also include any further classifications i.e. human, elf, bird, etc.
# Planeswalkers also have a sub_type (with the exception of one card, The Wanderer) which are the name of the character i.e. Jace, Chandra, Oko, etc

# %%
for index in df.index:
    try:
        df.loc[index, 'sub_type'] = df.loc[index, 'type_line'].split(' // ')[0].split(' — ')[1]
    except:
        df.loc[index, 'sub_type'] = 'NONE'
    try:
        df.loc[index, 'sub_type_back'] = df.loc[index, 'type_line'].split(' // ')[1].split(' — ')[1]
    except:
        df.loc[index, 'sub_type_back'] = 'NONE'

# %%
df.head()
# Out:
#   object                 name  \
# 0   card           Static Orb
# 1   card  Sensory Deprivation
# 2   card       Road of Return
# 3   card           Storm Crow
# 4   card       Walking Sponge
#
#                                         scryfall_uri  layout mana_cost  cmc  \
# 0  https://scryfall.com/card/7ed/319/static-orb?u...  normal       {3}  3.0
# 1  https://scryfall.com/card/m14/71/sensory-depri...  normal       {U}  1.0
# 2  https://scryfall.com/card/c19/34/road-of-retur...  normal    {G}{G}  2.0
# 3  https://scryfall.com/card/9ed/100/storm-crow?u...  normal    {1}{U}  2.0
# 4  https://scryfall.com/card/ulg/47/walking-spong...  normal    {1}{U}  2.0
#
#             type_line                                        oracle_text  \
# 0            Artifact  As long as Static Orb is untapped, players can...
# 1  Enchantment — Aura   Enchant creature\nEnchanted creature gets -3/-0.
# 2             Sorcery  Choose one —\n• Return target permanent card f...
# 3     Creature — Bird  Flying (This creature can't be blocked except ...
# 4   Creature — Sponge  {T}: Target creature loses your choice of flyi...
#
#   colors color_identity                                         legalities  \
# 0     []             []                      legacy vintage commander duel
# 1    [U]            [U]  pioneer modern legacy pauper vintage penny com...
# 2    [G]            [G]                      legacy vintage commander duel
# 3    [U]            [U]  modern legacy pauper vintage penny commander duel
# 4    [U]            [U]                      legacy vintage commander duel
#
#      rarity power toughness card_faces loyalty    card_type oracle_text_back  \
# 0      rare  NONE      NONE       NONE    NONE     Artifact             NONE
# 1    common  NONE      NONE       NONE    NONE  Enchantment             NONE
# 2      rare  NONE      NONE       NONE    NONE      Sorcery             NONE
# 3    common     1         2       NONE    NONE     Creature             NONE
# 4  uncommon     1         1       NONE    NONE     Creature             NONE
#
#   colors_back power_back toughness_back loyalty_back card_type_back  \
# 0        NONE       NONE           NONE         NONE           NONE
# 1        NONE       NONE           NONE         NONE           NONE
# 2        NONE       NONE           NONE         NONE           NONE
# 3        NONE       NONE           NONE         NONE           NONE
# 4        NONE       NONE           NONE         NONE           NONE
#
#   mana_cost_back super_type super_type_back sub_type sub_type_back
# 0           NONE       NONE            NONE     NONE          NONE
# 1           NONE       NONE            NONE     Aura          NONE
# 2           NONE       NONE            NONE     NONE          NONE
# 3           NONE       NONE            NONE     Bird          NONE
# 4           NONE       NONE            NONE   Sponge          NONE

# %%
df.columns
# Out:
# Index(['object', 'name', 'scryfall_uri', 'layout', 'mana_cost', 'cmc',
#        'type_line', 'oracle_text', 'colors', 'color_identity', 'legalities',
#        'rarity', 'power', 'toughness', 'card_faces', 'loyalty', 'card_type',
#        'oracle_text_back', 'colors_back', 'power_back', 'toughness_back',
#        'loyalty_back', 'card_type_back', 'mana_cost_back', 'super_type',
#        'super_type_back', 'sub_type', 'sub_type_back'],
#       dtype='object')

# %%
# reordering the columns
df = df[['name', 'layout', 'colors', 'color_identity', 'mana_cost', 'cmc', 'type_line', 'card_type', 'super_type', 
    'sub_type', 'oracle_text', 'legalities', 'rarity', 'power', 'toughness', 'loyalty', 'card_faces',
    'oracle_text_back', 'colors_back', 'power_back', 'toughness_back', 'loyalty_back', 'card_type_back',
    'super_type_back', 'sub_type_back', 'mana_cost_back', 'scryfall_uri'
   ]]

# %% [markdown]
# ___
# I'd like to make a column that denotes if a card has an acivated ability and another column if the card has a triggered ability. I did have these as seperate processes then later realized I can combine them to save on computing power. To further increase performance I could do cluster computing with scala, but that might not be worth the hassle and may not save time in the long run.

# %%
for index in df.index:
    # an acitvated ability on a card is denoted by a ':'
    if ':' in df.loc[index, 'oracle_text'] or ':' in df.loc[index, 'oracle_text_back']:
        df.loc[index, 'activated_ability'] = 1
    else:
        df.loc[index, 'activated_ability'] = 0

    # triggered abilities occur when certain conditions are met and use the keywords 'when', 'whenever', and 'at'
    if re.search(r'\bwhenever\b', df.loc[index, 'oracle_text'].lower()) != None or re.search(r'\bwhenever\b', df.loc[index, 'oracle_text_back'].lower()) != None:
        df.loc[index, 'triggered_ability'] = 1
    elif re.search(r'\bwhen\b', df.loc[index, 'oracle_text'].lower()) != None or re.search(r'\bwhen\b', df.loc[index, 'oracle_text_back'].lower()) != None:
        df.loc[index, 'triggered_ability'] = 1
    elif re.search(r'\bat\b', df.loc[index, 'oracle_text'].lower()) != None or re.search(r'\bat\b', df.loc[index, 'oracle_text_back'].lower()) != None:
        df.loc[index, 'triggered_ability'] = 1
    else:
        df.loc[index, 'triggered_ability'] = 0
        
    # While I'm at it, I want to git rid of all the '/n' from the oracle texts
    df.loc[index, 'oracle_text'] = df.loc[index, 'oracle_text'].replace('\n', ' ')
    df.loc[index, 'oracle_text_back'] = df.loc[index, 'oracle_text_back'].replace('\n', ' ')

# %% [markdown]
# ___

# %% [markdown]
# Now I need to clean up the oracle_text and oracle_text_back columns using RegEx

# %%
# # first we need to get rid of all the '\n'
# for index in df.index:
#     df.loc[index, 'oracle_text'] = df.loc[index, 'oracle_text'].replace('\n', ' ')
#     df.loc[index, 'oracle_text_back'] = df.loc[index, 'oracle_text_back'].replace('\n', ' ')

# %%
# instatiate the tokenizer
tknr = RegexpTokenizer(r"[a-zA-Z{}+'0-9-/−]+")

odf = df.loc[df['oracle_text'] != 'NONE']
obdf = df.loc[df['oracle_text_back'] != 'NONE']

# start with empty lists
tokens = []
tokens_back = []

# fill the lists with tokenized versions of each card's oracle_text
for card in odf['oracle_text']:
    tokens.append(" ".join(tknr.tokenize(card.lower())))

for card in obdf['oracle_text_back']:
    tokens_back.append(" ".join(tknr.tokenize(card.lower())))

# update the oracle_text columns
df.loc[odf.index, 'oracle_text_token'] = tokens
df.loc[obdf.index, 'oracle_text_back_token'] = tokens_back

# %%
# reordering the columns
df = df[['name', 'layout', 'colors', 'color_identity', 'mana_cost', 'cmc', 'type_line', 'card_type', 'super_type', 
    'sub_type', 'oracle_text', 'oracle_text_token', 'legalities', 'rarity', 'power', 'toughness', 'loyalty',
    'card_faces', 'activated_ability', 'triggered_ability', 'oracle_text_back', 'oracle_text_back_token',
    'colors_back', 'power_back', 'toughness_back', 'loyalty_back', 'card_type_back', 'super_type_back',
    'sub_type_back', 'mana_cost_back', 'scryfall_uri'
   ]]

df.fillna('NONE', inplace=True)

# %%
df.head()
# Out:
#                   name  layout colors color_identity mana_cost  cmc  \
# 0           Static Orb  normal     []             []       {3}  3.0
# 1  Sensory Deprivation  normal    [U]            [U]       {U}  1.0
# 2       Road of Return  normal    [G]            [G]    {G}{G}  2.0
# 3           Storm Crow  normal    [U]            [U]    {1}{U}  2.0
# 4       Walking Sponge  normal    [U]            [U]    {1}{U}  2.0
#
#             type_line    card_type super_type sub_type  \
# 0            Artifact     Artifact       NONE     NONE
# 1  Enchantment — Aura  Enchantment       NONE     Aura
# 2             Sorcery      Sorcery       NONE     NONE
# 3     Creature — Bird     Creature       NONE     Bird
# 4   Creature — Sponge     Creature       NONE   Sponge
#
#                                          oracle_text  \
# 0  As long as Static Orb is untapped, players can...
# 1    Enchant creature Enchanted creature gets -3/-0.
# 2  Choose one — • Return target permanent card fr...
# 3  Flying (This creature can't be blocked except ...
# 4  {T}: Target creature loses your choice of flyi...
#
#                                    oracle_text_token  \
# 0  as long as static orb is untapped players can'...
# 1     enchant creature enchanted creature gets -3/-0
# 2  choose one return target permanent card from y...
# 3  flying this creature can't be blocked except b...
# 4  {t} target creature loses your choice of flyin...
#
#                                           legalities    rarity power  \
# 0                      legacy vintage commander duel      rare  NONE
# 1  pioneer modern legacy pauper vintage penny com...    common  NONE
# 2                      legacy vintage commander duel      rare  NONE
# 3  modern legacy pauper vintage penny commander duel    common     1
# 4                      legacy vintage commander duel  uncommon     1
#
#   toughness loyalty card_faces  activated_ability  triggered_ability  \
# 0      NONE    NONE       NONE                0.0                0.0
# 1      NONE    NONE       NONE                0.0                0.0
# 2      NONE    NONE       NONE                0.0                0.0
# 3         2    NONE       NONE                0.0                0.0
# 4         1    NONE       NONE                1.0                0.0
#
#   oracle_text_back oracle_text_back_token colors_back power_back  \
# 0             NONE                   NONE        NONE       NONE
# 1             NONE                   NONE        NONE       NONE
# 2             NONE                   NONE        NONE       NONE
# 3             NONE                   NONE        NONE       NONE
# 4             NONE                   NONE        NONE       NONE
#
#   toughness_back loyalty_back card_type_back super_type_back sub_type_back  \
# 0           NONE         NONE           NONE            NONE          NONE
# 1           NONE         NONE           NONE            NONE          NONE
# 2           NONE         NONE           NONE            NONE          NONE
# 3           NONE         NONE           NONE            NONE          NONE
# 4           NONE         NONE           NONE            NONE          NONE
#
#   mana_cost_back                                       scryfall_uri
# 0           NONE  https://scryfall.com/card/7ed/319/static-orb?u...
# 1           NONE  https://scryfall.com/card/m14/71/sensory-depri...
# 2           NONE  https://scryfall.com/card/c19/34/road-of-retur...
# 3           NONE  https://scryfall.com/card/9ed/100/storm-crow?u...
# 4           NONE  https://scryfall.com/card/ulg/47/walking-spong...

# %% [markdown]
# ___

# %%
# save out our cleaned df
df.to_csv('../Data/cards_cleaned.csv', index=False)
